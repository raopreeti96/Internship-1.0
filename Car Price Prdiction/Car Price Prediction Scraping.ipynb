# %%
#Lets import all the required libraries 
import selenium # Libraries that is used to work  with selenium
from selenium import webdriver # importing web driver module from selenium to open automated edge window
import pandas as pd # to create dataframe
from selenium.webdriver.common.by import By#importing inbuild class BY
import warnings #to ignore any sort warnings
warnings.filterwarnings('ignore')
import time# used to stop search engine for few seconds

# %%
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"C:\Users\saura\OneDrive\Desktop\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="18dd93ea4346528e1b0515a2b35a929a")>

# %%
url="https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"

# %%
driver.get(url)

# %%
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')

# %%
len(Brand)
# Out:
# 1164

# %%
# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

# %%
len(Year_Model)
# Out:
# 1164

# %%
Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

# %%
len(Car_Name)
# Out:
# 1164

# %%
Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')

# %%
len(Model)
# Out:
# 1164

# %%
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')

# %%
len(Variant)
# Out:
# 1164

# %%
# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')

# %%
len(driven_kilometer)
# Out:
# 1164

# %%
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')

# %%
len(fuel)
# Out:
# 1164

# %%
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')

# %%
len(number_of_owners)
# Out:
# 1164

# %%
# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
len(Price)
# Out:
# 1164

# %%
import pandas as  pd

# %%
car_data1=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data1['Location']='Delhi'

# %%
car_data1
# Out:
#         Brand Year_Model            Car_Name                  Model  \
# 0     HYUNDAI       2010               [I10]                ERA 1.1
# 1         KIA       2020            [SELTOS]            GTX+ 1.4 MT
# 2         KIA       2020            [SELTOS]        GTX + AT PETROL
# 3     Hyundai       2014      [SANTRO, XING]                GL PLUS
# 4       Skoda       2021            [KUSHAQ]       STYLE 1.5 TSI MT
# ...       ...        ...                 ...                    ...
# 1159   MARUTI       2018   [SUZUKI, CELERIO]                VXI CNG
# 1160   Maruti       2020     [Suzuki, Swift]                    LXI
# 1161  Hyundai       2020  [GRAND, I10, NIOS]  SPORTZ 1.2 KAPPA VTVT
# 1162    HONDA       2019             [AMAZE]          1.2L I-VTEC E
# 1163  Renault       2019              [Kwid]                    RXL
#
#         Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %%
car_data1.to_csv('car_data1')

# %%
data=pd.read_csv("car_data1")

# %%
data.head()
# Out:
#    Unnamed: 0    Brand  Year_Model            Car_Name             Model  \
# 0           0  HYUNDAI        2010             ['I10']           ERA 1.1
# 1           1      KIA        2020          ['SELTOS']       GTX+ 1.4 MT
# 2           2      KIA        2020          ['SELTOS']   GTX + AT PETROL
# 3           3  Hyundai        2014  ['SANTRO', 'XING']           GL PLUS
# 4           4    Skoda        2021          ['KUSHAQ']  STYLE 1.5 TSI MT
#
#      Variant driven_kilometer    fuel number_of_owners      Price Location
# 0     Manual        46,523 KM  PETROL        1ST OWNER   1,68,000    Delhi
# 1     Manual         6,003 KM  PETROL        1ST OWNER  16,89,000    Delhi
# 2  Automatic         9,417 KM  PETROL        1ST OWNER  16,73,000    Delhi
# 3     Manual        43,944 KM  PETROL        1ST OWNER   2,86,000    Delhi
# 4     Manual         7,182 KM  PETROL        1ST OWNER  17,01,000    Delhi

# %%
data.shape
# Out:
# (1164, 11)

# %% [markdown]
# # Next Data

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"C:\Users\saura\OneDrive\Desktop\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="13daf78dd7bfd65fb4939872a804a8c3")>

# %%
url="https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"

# %%
driver.get(url)

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data2=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data2['Location']='Mumbai'

# %%
car_data2
# Out:
#           Brand Year_Model                 Car_Name             Model  \
# 0         HONDA       2017                   [CITY]     VX CVT PETROL
# 1        Maruti       2013  [Suzuki, Wagon, R, 1.0]               LXI
# 2       Renault       2016                   [Kwid]               RXT
# 3        Maruti       2012      [Suzuki, Alto, K10]               VXI
# 4         Honda       2013                   [City]   1.5 E MT PETROL
# ..          ...        ...                      ...               ...
# 415       Skoda       2016                  [Rapid]  1.6 MPI STYLE AT
# 416        Tata       2019                [Harrier]   XZ 2.0L Kryotec
# 417      Maruti       2019   [Suzuki, New, Wagon-R]     LXI CNG 1.0 L
# 418     Hyundai       2020                   [AURA]             S CNG
# 419  Volkswagen       2017                   [AMEO]      HIGHLINE 1.2
#
#        Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %%
car_data2.to_csv('car_data2')

# %%
car_data2
# Out:
#           Brand Year_Model                 Car_Name             Model  \
# 0         HONDA       2017                   [CITY]     VX CVT PETROL
# 1        Maruti       2013  [Suzuki, Wagon, R, 1.0]               LXI
# 2       Renault       2016                   [Kwid]               RXT
# 3        Maruti       2012      [Suzuki, Alto, K10]               VXI
# 4         Honda       2013                   [City]   1.5 E MT PETROL
# ..          ...        ...                      ...               ...
# 415       Skoda       2016                  [Rapid]  1.6 MPI STYLE AT
# 416        Tata       2019                [Harrier]   XZ 2.0L Kryotec
# 417      Maruti       2019   [Suzuki, New, Wagon-R]     LXI CNG 1.0 L
# 418     Hyundai       2020                   [AURA]             S CNG
# 419  Volkswagen       2017                   [AMEO]      HIGHLINE 1.2
#
#        Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"C:\Users\saura\OneDrive\Desktop\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="c35ef878daac57e25d2ca70ef84dce32")>

# %%
url="https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"

# %%
driver.get(url)

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data3=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data3['Location']='Bengalore'

# %%
car_data3.to_csv('car_data3')

# %%
car_data3
# Out:
#        Brand Year_Model         Car_Name                   Model    Variant  \
# 0       TATA       2016          [TIAGO]         XZ 1.2 REVOTRON     Manual
# 1     Nissan       2022        [MAGNITE]                   XL MT     Manual
# 2      Honda       2014          [Amaze]        1.2 SX MT I VTEC     Manual
# 3    HYUNDAI       2013            [I20]            ASTA (O) 1.2     Manual
# 4     Maruti       2017  [Suzuki, Swift]                     VXI     Manual
# ..       ...        ...              ...                     ...        ...
# 495     Tata       2019          [NEXON]                XZA+ 1.5  Automatic
# 496   Maruti       2017  [Suzuki, Dzire]            ZXI Plus AMT  Automatic
# 497  HYUNDAI       2017          [CRETA]      SX PLUS 1.6 PETROL     Manual
# 498    Honda       2018           [City]           VX CVT PETROL  Automatic
# 499     FORD       2015       [ECOSPORT]  1.5 TITANIUM TI VCT AT  Automatic
#
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"C:\Users\saura\OneDrive\Desktop\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="d3162f80e8ae83ccc1f46b98ec18f70a")>

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"C:\Users\saura\OneDrive\Desktop\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="0d03b0a9124f88b7041b0fbe12c18efe")>

# %%
url="https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"

# %%
driver.get(url)

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7684\3334714550.py in <module>
#      60     name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
#      61     for i in name:
# ---> 62         fuel.append(i.text)
#      63 except NoSuchElementException:
#      64     fuel.append('Nan')
#
# D:\Install Software\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      87     def text(self) -> str:
#      88         """The text of the element."""
# ---> 89         return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#      90
#      91     def click(self) -> None:
#
# D:\Install Software\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     408             params = {}
#     409         params["id"] = self._id
# ...

# %%
car_data4=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data4['Location']='Bangalore'

# %%
car_data4.to_csv('car_data4')

# %%
car_data4
# Out:
#         Brand   Model                         Variant Manufacturing Year  \
# 0     Hyundai   VENUE  1.0 TURBO GDI SX+ AT Automatic               2019
# 1     Hyundai     i20                 ASTA 1.2 Manual               2011
# 2      Maruti  Ertiga                      VXI Manual               2016
# 3     Hyundai     i20             SPORTZ 1.2 O Manual               2011
# 4     Hyundai   Creta           SX PLUS AT 1.6 PETROL               2017
# ...       ...     ...                             ...                ...
# 1217  Hyundai   GRAND            MAGNA 1.2 KAPPA VTVT               2020
# 1218    Honda    Brio                            S MT               2014
# 1219   Maruti   Swift                      VXI Manual               2021
# 1220   Datsun      Go                        T Manual               2016
# 1221  Hyundai   Verna             FLUIDIC 1.6 CRDI SX               2011
#
#      Driven Kilometer    Fuel Number of Owners      Price   Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data5=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data5['Location']='Hyderabad'

# %%
car_data5.to_csv('car_data5')

# %%
car_data5
# Out:
#           Brand Year_Model                Car_Name                     Model  \
# 0        Maruti       2012  [Suzuki, Swift, Dzire]             ZXI 1.2 BS IV
# 1       Hyundai       2018                 [Verna]                1.4 VTVT E
# 2       Hyundai       2014            [Elite, i20]                SPORTZ 1.2
# 3       Hyundai       2020                 [Creta]              S 1.5 PETROL
# 4         Honda       2016                 [Amaze]            1.2 SMT I VTEC
# ..          ...        ...                     ...                       ...
# 535      MARUTI       2017     [SUZUKI, ALTO, K10]               VXI (O) AMT
# 536      Maruti       2019     [Suzuki, S, PRESSO]                  VXI PLUS
# 537       HONDA       2015                  [CITY]          1.5L I-VTEC V MT
# 538      MARUTI       2019         [SUZUKI, SWIFT]                       VXI
# 539  Volkswagen       2020                  [Polo]  HIGHLINE PLUS 1.0 TSI MT
#
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data6=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data6['Location']='Ahmedabad'

# %%
car_data6.to_csv('car_data6')

# %%
car_data6
# Out:
#        Brand Year_Model             Car_Name             Model    Variant  \
# 0    Hyundai       2019              [Xcent]             S 1.2     Manual
# 1     Maruti       2017  [Suzuki, Alto, 800]               LXI     Manual
# 2       Tata       2021              [NEXON]         XZ PETROL     Manual
# 3      Honda       2018               [Jazz]          1.2 V MT     Manual
# 4     Maruti       2020   [Suzuki, S, Cross]         ALPHA 1.5     Manual
# ..       ...        ...                  ...               ...        ...
# 399   Maruti       2016      [Suzuki, Swift]               VXI     Manual
# 400  Hyundai       2014              [Xcent]     SX AT 1.2 (O)  Automatic
# 401    HONDA       2018              [AMAZE]     1.2L I-VTEC S     Manual
# 402   Maruti       2021     [Suzuki, Baleno]  DELTA PETROL 1.2     Manual
# 403   MARUTI       2019  [SUZUKI, ALTO, 800]               LXI     Manual
#
#     driven_kilometer    fuel number_of_owners      Price   Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data7=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data7['Location']='Gurgaon'

# %%
car_data7.to_csv('car_data7')

# %%
car_data7
# Out:
#        Brand Year_Model                Car_Name                 Model  \
# 0      Honda       2011                  [City]           S MT PETROL
# 1       Jeep       2019               [Compass]  1.4 LONGITUDE (O) AT
# 2       Jeep       2019               [Compass]           2.0 LIMITED
# 3      Honda       2012                  [Brio]       1.2 V MT I VTEC
# 4      Skoda       2020                 [Rapid]        ACTIVE 1.0 TSI
# ..       ...        ...                     ...                   ...
# 775   Maruti       2020     [Suzuki, S, PRESSO]           LXI (O) CNG
# 776  HYUNDAI       2019                 [CRETA]           1.4 EX CRDI
# 777  Hyundai       2016            [Elite, i20]              ASTA 1.2
# 778   Maruti       2018     [Suzuki, Alto, 800]                   LXI
# 779   Maruti       2019  [Suzuki, New, Wagon-R]           1.0 LXI (O)
#
#        Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data8=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data8['Location']='Chennai'

# %%
car_data8.to_csv('car_data8')

# %%
car_data8
# Out:
#           Brand Year_Model            Car_Name                        Model  \
# 0       Hyundai       2016             [Verna]        FLUIDIC 4S 1.6 VTVT S
# 1         Honda       2014             [Amaze]               1.2 SMT I VTEC
# 2          Ford       2019          [Ecosport]  1.5 TITANIUM PLUS TI VCT AT
# 3          Tata       2020             [Tiago]        XZA+ DUAL TONE 1.2RTN
# 4        Maruti       2017    [Suzuki, Baleno]              ZETA PETROL 1.2
# ..          ...        ...                 ...                          ...
# 454     Hyundai       2021  [GRAND, I10, NIOS]        SPORTZ 1.2 KAPPA VTVT
# 455     Hyundai       2018             [Verna]                  1.6 EX CRDI
# 456  Volkswagen       2018              [Polo]       COMFORTLINE 1.0 PETROL
# 457      Maruti       2013     [Suzuki, Swift]                          VXI
# 458     Renault       2021              [Kwid]                          RXT
#
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data9=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data9['Location']='Pune'

# %%
car_data9.to_csv('car_data9')

# %%
car_data9
# Out:
#         Brand Year_Model                 Car_Name             Model  \
# 0      Nissan       2021                [MAGNITE]         XE 1.0 MT
# 1     Hyundai       2011                    [i20]          ASTA 1.2
# 2    Mahindra       2016                   [Thar]    CRDE 4X4 BS IV
# 3      Maruti       2010    [Suzuki, ZEN, ESTILO]               LXI
# 4       Honda       2012                   [City]      V AT SUNROOF
# ..        ...        ...                      ...               ...
# 619    MARUTI       2016  [SUZUKI, WAGON, R, 1.0]           VXI AMT
# 620     Honda       2014                  [Amaze]    1.2 SMT I VTEC
# 621      Tata       2017                  [Tiago]   XZ 1.2 REVOTRON
# 622     Honda       2018                   [WR-V]  1.5 i-DTEC VX MT
# 623    Maruti       2017          [Suzuki, Swift]               VXI
#
#        Variant driven_kilometer    fuel number_of_owners     Price Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data10=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data10['Location']='Noida'

# %%
car_data10.to_csv('car_data10')

# %%
car_data10
# Out:
#          Brand Year_Model                  Car_Name                Model  \
# 0        Honda       2015                   [Amaze]       1.2 SMT I VTEC
# 1      HYUNDAI       2020              [GRAND, I10]       MAGNA 1.2 VTVT
# 2       Maruti       2011   [Suzuki, WAGON, R, 1.0]                  VXI
# 3      HYUNDAI       2012                     [I10]     MAGNA 1.2 KAPPA2
# 4      Hyundai       2011                     [i10]     MAGNA 1.2 KAPPA2
# ...        ...        ...                       ...                  ...
# 1178    Maruti       2018   [Suzuki, Wagon, R, 1.0]              LXI CNG
# 1179  Mahindra       2022                    [Thar]  LX HT PETROL 4WD MT
# 1180   Renault       2019                    [Kwid]                  RXL
# 1181   HYUNDAI       2012                     [I20]           SPORTZ 1.2
# 1182    MARUTI       2019  [SUZUKI, VITARA, BREZZA]                  VDI
#
#      Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %% [markdown]
# # Next Data

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data11=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data11['Location']='Ghaziabad'

# %%
car_data11.to_csv('car_data11')

# %%
car_data11
# Out:
#          Brand Year_Model                  Car_Name                Model  \
# 0        HONDA       2012                    [CITY]          S MT PETROL
# 1        Honda       2016                    [City]         VX MT PETROL
# 2        Honda       2015                    [City]      1.5 E MT PETROL
# 3        Honda       2014                    [City]          V MT PETROL
# 4        HONDA       2015                    [CITY]         SV MT PETROL
# ...        ...        ...                       ...                  ...
# 1219    Maruti       2018   [Suzuki, Wagon, R, 1.0]              LXI CNG
# 1220  Mahindra       2022                    [Thar]  LX HT PETROL 4WD MT
# 1221   Renault       2019                    [Kwid]                  RXL
# 1222   HYUNDAI       2012                     [I20]           SPORTZ 1.2
# 1223    MARUTI       2019  [SUZUKI, VITARA, BREZZA]                  VDI
#
#      Variant driven_kilometer    fuel number_of_owners      Price   Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data12=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data12['Location']='Lucknow'

# %%
car_data12.to_csv('car_data12')

# %%
car_data12
# Out:
#         Brand Year_Model                 Car_Name                 Model  \
# 0    Mahindra       2015                   [Thar]        CRDE 4X4 BS IV
# 1      TOYOTA       2017               [FORTUNER]            2.8 4x4 AT
# 2      Maruti       2015  [Suzuki, Wagon, R, 1.0]                   VXI
# 3        TATA       2022                  [TIGOR]        XZ CNG 1.2 RTN
# 4     Hyundai       2017                    [Eon]          ERA PLUS (O)
# ..        ...        ...                      ...                   ...
# 118    Maruti       2020   [Suzuki, New, Wagon-R]         LXI CNG 1.0 L
# 119   HYUNDAI       2021                  [VENUE]  1.0L Turbo GDI SX MT
# 120    MARUTI       2020      [SUZUKI, S, PRESSO]                   VXI
# 121   HYUNDAI       2021                   [AURA]                 S CNG
# 122    DATSUN       2021               [REDI, GO]                     T
#
#        Variant driven_kilometer    fuel number_of_owners      Price Location
# ...

# %% [markdown]
# # NEXT DATA

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data13=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data13['Location']='Jaipur'

# %%
car_data13.to_csv('car_data13')

# %%
car_data13
# Out:
#         Brand Year_Model           Car_Name                  Model    Variant  \
# 0      MARUTI       2013    [SUZUKI, SWIFT]                    LXI     Manual
# 1    MAHINDRA       2019           [BOLERO]             Power+ SLX     Manual
# 2      Maruti       2018    [Suzuki, Swift]                VXI AMT  Automatic
# 3      MARUTI       2019      [SUZUKI, XL6]          ALPHA SHVS MT     Manual
# 4      Maruti       2019     [Suzuki, EECO]  5 STR WITH AC PLUSHTR     Manual
# ..        ...        ...                ...                    ...        ...
# 126    Maruti       2020     [Suzuki, Eeco]  5 STR WITH AC PLUSHTR     Manual
# 127    Maruti       2022  [Suzuki, Celerio]                    ZXI     Manual
# 128      Tata       2019       [TIAGO, NRG]                 PETROL     Manual
# 129    MARUTI       2019     [SUZUKI, ALTO]                    LXI     Manual
# 130    Maruti       2015     [Suzuki, Ciaz]                    ZXI     Manual
#
# ...

# %% [markdown]
# # NEXT DATA

# %%
url="https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"

# %%
driver.get(url)

# %%
# scraping  Flight Name
# Scraping details of product for which you want
Brand=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Brand.append(i.text.split(' ')[1])
except NoSuchElementException:
    Brand.append('Nan')


# scraping  Flight Name
Year_Model=[]
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Year_Model.append(i.text.split(' ')[0])
except NoSuchElementException:
    Year_Model.append('Nan')

Car_Name=[]
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//h2[@class='_2lmIw']")
    for i in name:
        Car_Name.append(i.text.split(' ')[2:])
except NoSuchElementException:
    Car_Name.append('Nan')

Model=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[1]")
    for i in name:
        Model.append(i.text)
except NoSuchElementException:
    Model.append('Nan')
    
# scraping  Flight Name
Variant=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_1hOnS']//li[3]")
    for i in name:
        Variant.append(i.text)
except NoSuchElementException:
    Variant.append('Nan')
    

# scraping  Flight Name
driven_kilometer=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[1]")
    for i in name:
        driven_kilometer.append(i.text)
except NoSuchElementException:
    driven_kilometer.append('Nan')
    
# scraping  Flight Name
fuel=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[3]")
    for i in name:
        fuel.append(i.text)
except NoSuchElementException:
    fuel.append('Nan')
    
    
# scraping  Flight Name
number_of_owners=[]
try:
    name = driver.find_elements(By.XPATH,"//ul[@class='_13yb6']//li[2]")
    for i in name:
         number_of_owners.append(i.text)
except NoSuchElementException:
     number_of_owners.append('Nan')
        
    

# scraping  Flight Name
Price=[]
    
try:
    name = driver.find_elements(By.XPATH,"//div[@class='_18ToE']/span")
    for i in name:
         Price.append(i.text.replace('₹','')) 
except NoSuchElementException:
    Price.append('Nan')

# %%
car_data14=pd.DataFrame({"Brand":Brand,"Year_Model":Year_Model,"Car_Name":Car_Name,"Model":Model,"Variant":Variant,"driven_kilometer":driven_kilometer,"fuel":fuel,"number_of_owners":number_of_owners,"Price":Price})

# %%
car_data14['Location']='Kolkata'

# %%
car_data14.to_csv('car_data14')

# %%
car_data14
# Out:
#        Brand Year_Model             Car_Name                Model Variant  \
# 0     Toyota       2011              [Etios]                    V  Manual
# 1     Maruti       2015  [Suzuki, Alto, 800]                  LXI  Manual
# 2      HONDA       2015               [CITY]     1.5L I-VTEC V MT  Manual
# 3    HYUNDAI       2010                [I10]            MAGNA 1.2  Manual
# 4    Hyundai       2011                [i10]              ERA 1.1  Manual
# ..       ...        ...                  ...                  ...     ...
# 214   Maruti       2014  [Suzuki, Alto, 800]                  VXI  Manual
# 215   MARUTI       2018      [SUZUKI, SWIFT]                  VXI  Manual
# 216  Hyundai       2018         [Elite, i20]  MAGNA EXECUTIVE 1.2  Manual
# 217   Maruti       2020      [Suzuki, DZIRE]                  VXI  Manual
# 218  Hyundai       2015        [i20, Active]               1.2 SX  Manual
#
#     driven_kilometer    fuel number_of_owners     Price Location
# ...
