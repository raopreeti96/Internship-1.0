# %%
#Lets import all the required libraries 
import selenium # Libraries that is used to work  with selenium
from selenium import webdriver # importing web driver module from selenium to open automated edge window
import pandas as pd # to create dataframe
from selenium.webdriver.common.by import By#importing inbuild class BY
import warnings #to ignore any sort warnings
warnings.filterwarnings('ignore')
import time# used to stop search engine for few seconds

# %%
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="66b2419441af47e7f07bf82acf209856")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=JAI&destinationCountry=IN&flexi=0&flight_depart_date=06%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=45747080776&version=1.1&viewName=normal'

# %%
driver.get(url)

# %%
for _ in range(200):

    driver.execute_script("window.scrollBy(0,1000)")

# %%
# Scraping details of product for which you want
Flight_Name=[]

# %%
len(Flight_Name)
# Out:
# 160

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')

# %%
From=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# %%
len(From)
# Out:
# 160

# %%
To=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
len(To)
# Out:
# 160

# %%
Time_Taken=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')

# %%
len(Time_Taken)
# Out:
# 160

# %%
Stopage=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')

# %%
len(Stopage)
# Out:
# 160

# %%
Price=[]

# %%
#scraping the data of Price
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')

# %%
len(Price)
# Out:
# 160

# %%
Departure_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')

# %%
len(Departure_Time)
# Out:
# 160

# %%
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
len(Arrived_Time)
# Out:
# 160

# %%
#Lets make dataframe
import pandas as pd

# %%
Flight_Prediction1=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"04-jan-2023"})

# %%
"Date Of Journey":"04-jan-2023"(flight date),

# %%
Flight_Prediction1.to_csv('Flight_Prediction_01')

# %%
Flight_Prediction1
# Out:
#     Flight Name       From      To Time Taken Stopage Departure Time  \
# 0      Go First  New Delhi  Mumbai    14h 20m  1 Stop          18:00
# 1      Go First  New Delhi  Mumbai     8h 40m  1 Stop          04:55
# 2      Go First  New Delhi  Mumbai     8h 05m  1 Stop          22:00
# 3      Go First  New Delhi  Mumbai     5h 15m  1 Stop          05:00
# 4      Go First  New Delhi  Mumbai     6h 00m  1 Stop          10:40
# ..          ...        ...     ...        ...     ...            ...
# 155    Air Asia  New Delhi  Mumbai     8h 45m  1 Stop          07:30
# 156    Go First  New Delhi  Mumbai     7h 40m  1 Stop          10:45
# 157      IndiGo  New Delhi  Mumbai     6h 55m  1 Stop          13:00
# 158      IndiGo  New Delhi  Mumbai     9h 00m  1 Stop          09:40
# 159      IndiGo  New Delhi  Mumbai     6h 30m  1 Stop          09:40
#
#        Arrived Time   Price Date Of Journey
# 0             08:00   6,454     04-jan-2023
# 1             09:15   6,632     04-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # NEXT DATA

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="6d87cf89995cc8ce66c549a07544ff8e")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=05%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1170808134470'

# %%
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')

# %%
len(Flight_Name)
# Out:
# 153

# %%
From=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# %%
len(From)
# Out:
# 153

# %%
To=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
len(To)
# Out:
# 153

# %%
Time_Taken=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')

# %%
len(Time_Taken)
# Out:
# 153

# %%
Stopage=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')

# %%
len(Stopage)
# Out:
# 153

# %%
Price=[]

# %%
#scraping the data of Price
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')

# %%
len(Price)
# Out:
# 153

# %%
Departure_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')

# %%
len(Departure_Time)
# Out:
# 153

# %%
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
len(Arrived_Time)
# Out:
# 153

# %%
#Lets make dataframe
import pandas as pd

# %%
Flight_Prediction2=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"05-jan-2023"})

# %%
Flight_Prediction2.to_csv('Flight_Prediction_02')

# %%
driver.close()

# %% [markdown]
# # NEXT DATA

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="cdbc1d913c113bf527b3db22a764c0b1")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=05%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1170808134470'

# %%
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')

# %%
len(Flight_Name)
# Out:
# 62

# %%
From=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# %%
len(From)
# Out:
# 62

# %%
To=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
len(To)
# Out:
# 62

# %%
Time_Taken=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')

# %%
len(Time_Taken)
# Out:
# 62

# %%
Stopage=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')

# %%
len(Stopage)
# Out:
# 62

# %%
Price=[]

# %%
#scraping the data of Price
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')

# %%
len(Price)
# Out:
# 62

# %%
Departure_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')

# %%
len(Departure_Time)
# Out:
# 62

# %%
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
len(Arrived_Time)
# Out:
# 62

# %%
#Lets make dataframe
import pandas as pd

# %%
Flight_Prediction3=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"06-jan-2023"})

# %%
Flight_Prediction3.to_csv('Flight_Prediction_03')

# %%
Flight_Prediction3
# Out:
#    Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0     Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 1     Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 2     SpiceJet  New Delhi  Jaipur     1h 10m   Non Stop          20:10
# 3       IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 4       IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          20:30
# ..         ...        ...     ...        ...        ...            ...
# 57     Vistara  New Delhi  Jaipur    18h 35m     1 Stop          19:00
# 58   Air India  New Delhi  Jaipur    16h 35m  2 Stop(s)          20:40
# 59     Vistara  New Delhi  Jaipur     8h 35m  2 Stop(s)          11:00
# 60   Air India  New Delhi  Jaipur    16h 35m  2 Stop(s)          20:40
# 61   Air India  New Delhi  Jaipur    15h 15m  2 Stop(s)          22:00
#
#       Arrived Time   Price Date Of Journey
# 0            21:25   2,489     06-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="00730fb741aca69cb25395ea181bc331")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=05%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1170808134470'

# %%
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')

# %%
len(Flight_Name)
# Out:
# 66

# %%
From=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# %%
len(From)
# Out:
# 66

# %%
To=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
len(To)
# Out:
# 66

# %%
Time_Taken=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')

# %%
len(Time_Taken)
# Out:
# 66

# %%
Stopage=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')

# %%
len(Stopage)
# Out:
# 66

# %%
Price=[]

# %%
#scraping the data of Price
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')

# %%
len(Price)
# Out:
# 66

# %%
Departure_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')

# %%
len(Departure_Time)
# Out:
# 66

# %%
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
len(Arrived_Time)
# Out:
# 66

# %%
#Lets make dataframe
import pandas as pd

# %%
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"06-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_04')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 1         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 2         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 3   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          19:30
# 4       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# ..           ...        ...     ...        ...        ...            ...
# 61       Vistara  New Delhi  Jaipur    28h 50m  2 Stop(s)          14:45
# 62       Vistara  New Delhi  Jaipur    28h 50m  2 Stop(s)          14:45
# 63       Vistara  New Delhi  Jaipur    12h 15m  2 Stop(s)          07:20
# 64       Vistara  New Delhi  Jaipur     8h 35m  2 Stop(s)          11:00
# 65       Vistara  New Delhi  Jaipur    12h 25m  2 Stop(s)          07:10
#
#       Arrived Time   Price Date Of Journey
# 0            06:05   1,997     06-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="9e28cb2738ecabd9ae20616daedbce55")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=05%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1170808134470'

# %%
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67

# %%
len(To)
# Out:
# 134

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"09-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_05')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 1       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 2         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 3         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 4   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          06:50
# ..           ...        ...     ...        ...        ...            ...
# 62     Air India  New Delhi  Jaipur    15h 45m  2 Stop(s)          21:30
# 63       Vistara  New Delhi  Jaipur     6h 05m     1 Stop          07:30
# 64       Vistara  New Delhi  Jaipur    12h 05m     1 Stop          07:30
# 65       Vistara  New Delhi  Jaipur    14h 00m  2 Stop(s)          05:35
# 66       Vistara  New Delhi  Jaipur    12h 15m  2 Stop(s)          07:20
#
#       Arrived Time   Price Date Of Journey
# 0            21:25   1,997     09-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"10-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_06')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 1       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 2         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 3         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 4   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          06:50
# ..           ...        ...     ...        ...        ...            ...
# 63       Vistara  New Delhi  Jaipur    20h 00m  2 Stop(s)          17:35
# 64       Vistara  New Delhi  Jaipur    26h 00m  2 Stop(s)          17:35
# 65       Vistara  New Delhi  Jaipur     8h 35m  2 Stop(s)          11:00
# 66       Vistara  New Delhi  Jaipur    20h 00m  2 Stop(s)          17:35
# 67       Vistara  New Delhi  Jaipur    14h 00m  2 Stop(s)          05:35
#
#       Arrived Time   Price Date Of Journey
# 0            21:25   1,997     10-jan-2023
# ...

# %% [markdown]
# # Next Data

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=JAI&destinationCountry=IN&flexi=0&flight_depart_date=11%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=883075972840&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"11-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_07')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 1       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 2         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 3         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 4   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          06:50
# ..           ...        ...     ...        ...        ...            ...
# 63       Vistara  New Delhi  Jaipur    16h 55m  2 Stop(s)          20:40
# 64       Vistara  New Delhi  Jaipur    14h 00m  2 Stop(s)          05:35
# 65       Vistara  New Delhi  Jaipur    13h 40m  2 Stop(s)          05:55
# 66     Air India  New Delhi  Jaipur    15h 45m  2 Stop(s)          21:30
# 67       Vistara  New Delhi  Jaipur    12h 15m  2 Stop(s)          07:20
#
#       Arrived Time   Price Date Of Journey
# 0            21:25   1,997     11-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="9f5720f4f76b821ed4d3ddb86a10e25a")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=COK&destinationCountry=IN&flexi=0&flight_depart_date=12%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=218419795252&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"12-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_08')

# %%
Flight_Prediction4
# Out:
#    Flight Name       From     To Time Taken    Stopage Departure Time  \
# 0     Air Asia  New Delhi  Kochi    10h 50m     1 Stop          09:30
# 1     Air Asia  New Delhi  Kochi    12h 10m     1 Stop          08:10
# 2     Air Asia  New Delhi  Kochi    14h 35m     1 Stop          21:20
# 3       IndiGo  New Delhi  Kochi     7h 40m     1 Stop          22:55
# 4     Air Asia  New Delhi  Kochi     5h 55m     1 Stop          16:30
# ..         ...        ...    ...        ...        ...            ...
# 85   Air India  New Delhi  Kochi     9h 30m  2 Stop(s)          09:45
# 86   Air India  New Delhi  Kochi    12h 05m  2 Stop(s)          07:10
# 87   Air India  New Delhi  Kochi    13h 45m  2 Stop(s)          05:30
# 88   Air India  New Delhi  Kochi    26h 35m  2 Stop(s)          04:55
# 89   Air India  New Delhi  Kochi    38h 20m  2 Stop(s)          04:55
#
#       Arrived Time   Price Date Of Journey
# 0            20:20   6,711     12-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="3b9e6ee6de47fdc3de020cf3fdc3fb22")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=COK&destinationCountry=IN&flexi=0&flight_depart_date=13%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1672894801586&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"13-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_09')

# %%
Flight_Prediction4
# Out:
#    Flight Name       From     To Time Taken    Stopage Departure Time  \
# 0     Air Asia  New Delhi  Kochi    10h 50m     1 Stop          09:30
# 1     Air Asia  New Delhi  Kochi    12h 10m     1 Stop          08:10
# 2     Air Asia  New Delhi  Kochi    12h 55m     1 Stop          09:30
# 3     Air Asia  New Delhi  Kochi    14h 15m     1 Stop          08:10
# 4     Air Asia  New Delhi  Kochi     5h 55m     1 Stop          16:30
# ..         ...        ...    ...        ...        ...            ...
# 85   Air India  New Delhi  Kochi    22h 30m     1 Stop          09:00
# 86   Air India  New Delhi  Kochi    23h 30m     1 Stop          08:00
# 87   Air India  New Delhi  Kochi    24h 30m     1 Stop          07:00
# 88   Air India  New Delhi  Kochi    12h 30m     1 Stop          19:00
# 89   Air India  New Delhi  Kochi    38h 15m  2 Stop(s)          05:00
#
#       Arrived Time   Price Date Of Journey
# 0            20:20   6,711     13-jan-2023
# ...

# %%
driver.close()

# %%
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="76bb56e3715dcbd333bb8e13f234eccb")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=COK&destinationCountry=IN&flexi=0&flight_depart_date=14%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1672894994979&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 88
# 88
# 88
# 88
# 88
# 88
# 88
# 88

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"14-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_10')

# %%
Flight_Prediction4
# Out:
#    Flight Name       From     To Time Taken    Stopage Departure Time  \
# 0    Air India  New Delhi  Kochi     3h 05m   Non Stop          04:55
# 1     Air Asia  New Delhi  Kochi    12h 10m     1 Stop          08:10
# 2     Air Asia  New Delhi  Kochi    14h 15m     1 Stop          08:10
# 3     Air Asia  New Delhi  Kochi     8h 50m     1 Stop          21:20
# 4     Air Asia  New Delhi  Kochi    10h 50m     1 Stop          09:30
# ..         ...        ...    ...        ...        ...            ...
# 83    Go First  New Delhi  Kochi    10h 25m     1 Stop          09:00
# 84    Go First  New Delhi  Kochi    13h 25m     1 Stop          06:00
# 85   Air India  New Delhi  Kochi     9h 30m  2 Stop(s)          09:45
# 86   Air India  New Delhi  Kochi    12h 05m  2 Stop(s)          07:10
# 87   Air India  New Delhi  Kochi    13h 45m  2 Stop(s)          05:30
#
#       Arrived Time   Price Date Of Journey
# 0            08:00   7,215     14-jan-2023
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"6-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_11')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0     Air India  Mumbai  Hyderabad     1h 25m   Non Stop          06:00
# 1        IndiGo  Mumbai  Hyderabad     1h 25m   Non Stop          06:50
# 2     Air India  Mumbai  Hyderabad     1h 25m   Non Stop          11:00
# 3        IndiGo  Mumbai  Hyderabad     1h 35m   Non Stop          05:25
# 4        IndiGo  Mumbai  Hyderabad     1h 30m   Non Stop          16:05
# ..          ...     ...        ...        ...        ...            ...
# 109   Air India  Mumbai  Hyderabad    25h 00m     1 Stop          20:15
# 110   Air India  Mumbai  Hyderabad    14h 40m  2 Stop(s)          18:00
# 111   Air India  Mumbai  Hyderabad    12h 15m     1 Stop          21:05
# 112   Air India  Mumbai  Hyderabad    11h 30m  2 Stop(s)          12:15
# 113   Air India  Mumbai  Hyderabad    14h 55m     1 Stop          21:05
#
#        Arrived Time   Price Date Of Journey
# 0             07:25   5,103      6-jan-2023
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"7-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_12')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0     Air India  Mumbai  Hyderabad     1h 25m   Non Stop          06:00
# 1        IndiGo  Mumbai  Hyderabad     1h 25m   Non Stop          06:50
# 2        IndiGo  Mumbai  Hyderabad     1h 35m   Non Stop          05:25
# 3       Vistara  Mumbai  Hyderabad     1h 25m   Non Stop          06:20
# 4       Vistara  Mumbai  Hyderabad     1h 35m   Non Stop          19:20
# ..          ...     ...        ...        ...        ...            ...
# 107     Vistara  Mumbai  Hyderabad    10h 30m     1 Stop          06:30
# 108     Vistara  Mumbai  Hyderabad    11h 00m     1 Stop          06:00
# 109   Air India  Mumbai  Hyderabad    15h 30m     1 Stop          05:45
# 110   Air India  Mumbai  Hyderabad    24h 10m     1 Stop          21:05
# 111   Air India  Mumbai  Hyderabad    11h 30m  2 Stop(s)          12:15
#
#        Arrived Time   Price Date Of Journey
# 0             07:25   5,103      7-jan-2023
# ...

# %% [markdown]
# # Next DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"8-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_13')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0     Air India  Mumbai  Hyderabad     1h 25m   Non Stop          06:00
# 1       Vistara  Mumbai  Hyderabad     1h 25m   Non Stop          06:20
# 2        IndiGo  Mumbai  Hyderabad     1h 25m   Non Stop          06:50
# 3        IndiGo  Mumbai  Hyderabad     4h 05m     1 Stop          04:50
# 4        IndiGo  Mumbai  Hyderabad     4h 10m     1 Stop          05:35
# ..          ...     ...        ...        ...        ...            ...
# 106     Vistara  Mumbai  Hyderabad     7h 55m     1 Stop          11:55
# 107   Air India  Mumbai  Hyderabad     6h 00m     1 Stop          13:00
# 108   Air India  Mumbai  Hyderabad    15h 30m     1 Stop          05:45
# 109     Vistara  Mumbai  Hyderabad     7h 25m     1 Stop          12:25
# 110   Air India  Mumbai  Hyderabad    11h 30m  2 Stop(s)          12:15
#
#     Arrived Time   Price Date Of Journey
# 0          07:25   5,103      8-jan-2023
# ...

# %% [markdown]
# # NEXT Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"6-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_14')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From         To Time Taken   Stopage Departure Time  \
# 0      Air Asia  New Delhi  Bangalore     6h 40m    1 Stop          05:45
# 1        IndiGo  New Delhi  Bangalore     6h 15m    1 Stop          01:55
# 2        IndiGo  New Delhi  Bangalore     8h 10m    1 Stop          11:25
# 3      SpiceJet  New Delhi  Bangalore     2h 45m  Non Stop          22:00
# 4        IndiGo  New Delhi  Bangalore     6h 10m    1 Stop          06:10
# ..          ...        ...        ...        ...       ...            ...
# 155      IndiGo  New Delhi  Bangalore     5h 40m    1 Stop          13:40
# 156      IndiGo  New Delhi  Bangalore     6h 50m    1 Stop          07:45
# 157    Air Asia  New Delhi  Bangalore     7h 50m    1 Stop          07:15
# 158      IndiGo  New Delhi  Bangalore     8h 05m    1 Stop          13:00
# 159    Air Asia  New Delhi  Bangalore     7h 35m    1 Stop          16:55
#
#        Arrived Time   Price Date Of Journey
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 163
# 163
# 163
# 163
# 163
# 163
# 163
# 163

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"7-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_15')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From         To Time Taken    Stopage Departure Time  \
# 0     Air India  New Delhi  Bangalore     2h 45m   Non Stop          06:10
# 1        IndiGo  New Delhi  Bangalore     5h 20m     1 Stop          05:15
# 2        IndiGo  New Delhi  Bangalore     6h 30m     1 Stop          06:30
# 3        IndiGo  New Delhi  Bangalore     6h 50m     1 Stop          17:15
# 4        IndiGo  New Delhi  Bangalore     8h 10m     1 Stop          11:25
# ..          ...        ...        ...        ...        ...            ...
# 158    SpiceJet  New Delhi  Bangalore    21h 15m     1 Stop          19:50
# 159    Air Asia  New Delhi  Bangalore     5h 00m     1 Stop          07:10
# 160     Vistara  New Delhi  Bangalore     9h 15m  2 Stop(s)          08:20
# 161    Air Asia  New Delhi  Bangalore     7h 50m     1 Stop          07:15
# 162      IndiGo  New Delhi  Bangalore     5h 50m     1 Stop          16:45
#
#        Arrived Time   Price Date Of Journey
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 162
# 162
# 162
# 162
# 162
# 162
# 162
# 162

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"8-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_16')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From         To Time Taken   Stopage Departure Time  \
# 0      Go First  New Delhi  Bangalore     2h 50m  Non Stop          05:45
# 1        IndiGo  New Delhi  Bangalore     2h 50m  Non Stop          07:00
# 2        IndiGo  New Delhi  Bangalore     3h 10m  Non Stop          07:55
# 3      Go First  New Delhi  Bangalore    13h 25m    1 Stop          22:00
# 4      SpiceJet  New Delhi  Bangalore     2h 35m  Non Stop          20:30
# ..          ...        ...        ...        ...       ...            ...
# 157      IndiGo  New Delhi  Bangalore     5h 40m    1 Stop          13:40
# 158     Vistara  New Delhi  Bangalore     2h 45m  Non Stop          16:05
# 159     Vistara  New Delhi  Bangalore     2h 50m  Non Stop          14:10
# 160      IndiGo  New Delhi  Bangalore     7h 45m    1 Stop          09:25
# 161      IndiGo  New Delhi  Bangalore     4h 30m    1 Stop          13:40
#
#        Arrived Time   Price Date Of Journey
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 167
# 167
# 167
# 167
# 167
# 167
# 167
# 167

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"9-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_17')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From         To Time Taken   Stopage Departure Time  \
# 0      Air Asia  New Delhi  Bangalore     6h 40m    1 Stop          05:45
# 1      Air Asia  New Delhi  Bangalore     7h 50m    1 Stop          23:05
# 2        IndiGo  New Delhi  Bangalore     5h 25m    1 Stop          05:15
# 3        IndiGo  New Delhi  Bangalore     5h 25m    1 Stop          18:40
# 4        IndiGo  New Delhi  Bangalore     5h 25m    1 Stop          19:45
# ..          ...        ...        ...        ...       ...            ...
# 162     Vistara  New Delhi  Bangalore     2h 45m  Non Stop          16:05
# 163    Air Asia  New Delhi  Bangalore     7h 50m    1 Stop          07:15
# 164    Air Asia  New Delhi  Bangalore     7h 35m    1 Stop          16:55
# 165    Go First  New Delhi  Bangalore    13h 40m    1 Stop          05:50
# 166   Air India  New Delhi  Bangalore     2h 55m  Non Stop          13:30
#
#        Arrived Time   Price Date Of Journey
# ...

# %% [markdown]
# # Next Data

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=MAA&destinationCountry=IN&flight_depart_date=06%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1144488362753'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 141
# 141
# 141
# 141
# 141
# 141
# 141
# 141

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"6-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_18')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0      SpiceJet  New Delhi  Chennai     2h 35m   Non Stop          06:15
# 1        IndiGo  New Delhi  Chennai     2h 55m   Non Stop          07:10
# 2        IndiGo  New Delhi  Chennai     3h 00m   Non Stop          15:55
# 3     Air India  New Delhi  Chennai     2h 55m   Non Stop          11:50
# 4     Air India  New Delhi  Chennai     2h 55m   Non Stop          19:40
# ..          ...        ...      ...        ...        ...            ...
# 136   Air India  New Delhi  Chennai    23h 15m     1 Stop          20:15
# 137   Air India  New Delhi  Chennai    28h 50m     1 Stop          05:30
# 138     Vistara  New Delhi  Chennai    10h 10m  2 Stop(s)          14:10
# 139     Vistara  New Delhi  Chennai     8h 15m  2 Stop(s)          16:05
# 140   Air India  New Delhi  Chennai    12h 50m     1 Stop          06:50
#
#        Arrived Time   Price Date Of Journey
# 0             08:50   6,615      6-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 141
# 141
# 141
# 141
# 141
# 141
# 141
# 141

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"7-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_19')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0      SpiceJet  New Delhi  Chennai     2h 40m   Non Stop          18:50
# 1        IndiGo  New Delhi  Chennai     2h 50m   Non Stop          19:20
# 2        IndiGo  New Delhi  Chennai     2h 50m   Non Stop          23:50
# 3        IndiGo  New Delhi  Chennai     2h 55m   Non Stop          07:10
# 4        IndiGo  New Delhi  Chennai     2h 55m   Non Stop          08:25
# ..          ...        ...      ...        ...        ...            ...
# 136   Air India  New Delhi  Chennai    28h 50m  2 Stop(s)          05:30
# 137     Vistara  New Delhi  Chennai     8h 50m  2 Stop(s)          11:00
# 138     Vistara  New Delhi  Chennai     8h 15m  2 Stop(s)          16:05
# 139     Vistara  New Delhi  Chennai     8h 35m  2 Stop(s)          15:45
# 140   Air India  New Delhi  Chennai    23h 15m     1 Stop          20:15
#
#        Arrived Time   Price Date Of Journey
# 0             21:30   6,615      7-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 137
# 137
# 137
# 137
# 137
# 137
# 137
# 137

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"7-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_20')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0        IndiGo  New Delhi  Chennai     2h 50m   Non Stop          19:20
# 1        IndiGo  New Delhi  Chennai     2h 50m   Non Stop          23:50
# 2        IndiGo  New Delhi  Chennai     2h 55m   Non Stop          07:10
# 3        IndiGo  New Delhi  Chennai     2h 55m   Non Stop          08:25
# 4        IndiGo  New Delhi  Chennai     3h 00m   Non Stop          21:10
# ..          ...        ...      ...        ...        ...            ...
# 132   Air India  New Delhi  Chennai    12h 40m     1 Stop          06:50
# 133   Air India  New Delhi  Chennai     7h 20m     1 Stop          12:10
# 134     Vistara  New Delhi  Chennai     8h 50m  2 Stop(s)          11:00
# 135     Vistara  New Delhi  Chennai     8h 15m  2 Stop(s)          16:05
# 136     Vistara  New Delhi  Chennai    10h 10m  2 Stop(s)          14:10
#
#        Arrived Time   Price Date Of Journey
# 0             22:10   6,616      7-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="cce0a8afa34caf0b604f9f839d66506b")>

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=06%2F01%2F2023&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=576508787510&version=1.1&viewName=normal"
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 135
# 135
# 135
# 135
# 135
# 135
# 135
# 135

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"7-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_21')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0      Air Asia  New Delhi  Kolkata     5h 25m     1 Stop          07:10
# 1      Air Asia  New Delhi  Kolkata    11h 30m     1 Stop          20:40
# 2      Air Asia  New Delhi  Kolkata    14h 50m     1 Stop          21:45
# 3      Go First  New Delhi  Kolkata     5h 50m  2 Stop(s)          06:30
# 4      Go First  New Delhi  Kolkata     7h 20m     1 Stop          02:40
# ..          ...        ...      ...        ...        ...            ...
# 130     Vistara  New Delhi  Kolkata    10h 45m  2 Stop(s)          07:20
# 131   Air India  New Delhi  Kolkata     6h 05m     1 Stop          09:25
# 132   Air India  New Delhi  Kolkata    23h 50m     1 Stop          09:25
# 133     Vistara  New Delhi  Kolkata    11h 00m     1 Stop          08:50
# 134     Vistara  New Delhi  Kolkata     9h 15m     1 Stop          08:50
#
#        Arrived Time   Price Date Of Journey
# 0             12:35   7,319      7-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="5d86c4324f6c656af607984f3b8f5221")>

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=08%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1672982749498&viewName=normal"
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"8-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_22')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0      Air Asia  New Delhi  Kolkata     4h 40m     1 Stop          10:55
# 1      Air Asia  New Delhi  Kolkata     5h 25m     1 Stop          07:10
# 2      Air Asia  New Delhi  Kolkata    10h 30m     1 Stop          10:55
# 3      Air Asia  New Delhi  Kolkata    11h 30m     1 Stop          20:40
# 4      Air Asia  New Delhi  Kolkata    14h 50m     1 Stop          21:45
# ..          ...        ...      ...        ...        ...            ...
# 127     Vistara  New Delhi  Kolkata     7h 00m     1 Stop          12:50
# 128     Vistara  New Delhi  Kolkata     5h 30m     1 Stop          14:20
# 129     Vistara  New Delhi  Kolkata     8h 50m  2 Stop(s)          11:00
# 130     Vistara  New Delhi  Kolkata    12h 40m  2 Stop(s)          07:10
# 131     Vistara  New Delhi  Kolkata    10h 45m  2 Stop(s)          07:20
#
#        Arrived Time   Price Date Of Journey
# 0             15:35   7,319      8-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="35e85e96f777e902e5369f20248b0a14")>

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=08%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1672982749498&viewName=normal"
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 137
# 137
# 137
# 137
# 137
# 137
# 137
# 137

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"9-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_23')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0        IndiGo  New Delhi  Kolkata     4h 45m     1 Stop          14:55
# 1      Air Asia  New Delhi  Kolkata     5h 25m     1 Stop          07:10
# 2      Air Asia  New Delhi  Kolkata    11h 25m     1 Stop          15:05
# 3      Air Asia  New Delhi  Kolkata    11h 30m     1 Stop          20:40
# 4      Air Asia  New Delhi  Kolkata    14h 50m     1 Stop          21:45
# ..          ...        ...      ...        ...        ...            ...
# 132     Vistara  New Delhi  Kolkata     8h 35m     1 Stop          09:30
# 133     Vistara  New Delhi  Kolkata     9h 05m     1 Stop          09:00
# 134     Vistara  New Delhi  Kolkata    10h 35m     1 Stop          07:30
# 135     Vistara  New Delhi  Kolkata    11h 10m  2 Stop(s)          06:55
# 136   Air India  New Delhi  Kolkata    18h 30m     1 Stop          16:10
#
#        Arrived Time   Price Date Of Journey
# 0             19:40   7,319      9-jan-2023
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"10-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_24')

# %%
Flight_Prediction4
# Out:
#     Flight Name       From       To Time Taken    Stopage Departure Time  \
# 0      Air Asia  New Delhi  Kolkata     4h 40m     1 Stop          10:55
# 1        IndiGo  New Delhi  Kolkata     4h 45m     1 Stop          14:55
# 2      Air Asia  New Delhi  Kolkata     5h 25m     1 Stop          07:10
# 3        IndiGo  New Delhi  Kolkata     6h 10m     1 Stop          13:30
# 4      Air Asia  New Delhi  Kolkata    10h 30m     1 Stop          10:55
# ..          ...        ...      ...        ...        ...            ...
# 129     Vistara  New Delhi  Kolkata     8h 00m     1 Stop          08:50
# 130      IndiGo  New Delhi  Kolkata     4h 55m     1 Stop          07:45
# 131     Vistara  New Delhi  Kolkata    14h 40m     1 Stop          19:00
# 132     Vistara  New Delhi  Kolkata    12h 20m  2 Stop(s)          21:20
# 133   Air India  New Delhi  Kolkata    18h 30m     1 Stop          16:10
#
#        Arrived Time   Price Date Of Journey
# 0             15:35   7,319     10-jan-2023
# ...

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="a5fbdbc7fbdda1cdfecf894cd3c20538")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PAT&destinationCountry=IN&flexi=0&flight_depart_date=07%2F01%2F2023&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1114020979709&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"07-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_25')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From     To Time Taken    Stopage Departure Time  \
# 0        IndiGo  Mumbai  Patna     2h 20m   Non Stop          18:05
# 1      Go First  Mumbai  Patna     2h 25m   Non Stop          11:05
# 2      Go First  Mumbai  Patna     6h 05m     1 Stop          05:30
# 3      Go First  Mumbai  Patna     6h 40m     1 Stop          05:50
# 4      Go First  Mumbai  Patna    10h 10m     1 Stop          09:55
# ..          ...     ...    ...        ...        ...            ...
# 99      Vistara  Mumbai  Patna    12h 25m  2 Stop(s)          05:40
# 100     Vistara  Mumbai  Patna    11h 45m  2 Stop(s)          06:20
# 101     Vistara  Mumbai  Patna    19h 15m  2 Stop(s)          22:50
# 102     Vistara  Mumbai  Patna    19h 25m  2 Stop(s)          22:40
# 103     Vistara  Mumbai  Patna    23h 35m     1 Stop          18:30
#
#        Arrived Time   Price Date Of Journey
# 0             20:25   6,677     07-jan-2023
# 1             13:30   6,677     07-jan-2023
# ...

# %% [markdown]
# # Next DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 104

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"08-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_26')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From     To Time Taken    Stopage Departure Time  \
# 0        IndiGo  Mumbai  Patna     2h 20m   Non Stop          18:05
# 1      Go First  Mumbai  Patna     2h 25m   Non Stop          11:20
# 2      Go First  Mumbai  Patna    11h 30m     1 Stop          08:45
# 3      Go First  Mumbai  Patna    12h 45m     1 Stop          23:45
# 4      Go First  Mumbai  Patna    13h 35m     1 Stop          22:55
# ..          ...     ...    ...        ...        ...            ...
# 99      Vistara  Mumbai  Patna    11h 30m  2 Stop(s)          06:35
# 100     Vistara  Mumbai  Patna    12h 25m  2 Stop(s)          05:40
# 101     Vistara  Mumbai  Patna    11h 45m  2 Stop(s)          06:20
# 102     Vistara  Mumbai  Patna    11h 30m  2 Stop(s)          06:35
# 103     Vistara  Mumbai  Patna    12h 25m  2 Stop(s)          05:40
#
#        Arrived Time   Price Date Of Journey
# 0             20:25   6,677     08-jan-2023
# 1             13:45   6,677     08-jan-2023
# ...

# %% [markdown]
# # Next Data

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"09-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_27')

# %%
Flight_Prediction4
# Out:
#     Flight Name    From     To Time Taken    Stopage Departure Time  \
# 0        IndiGo  Mumbai  Patna     2h 20m   Non Stop          18:05
# 1      Go First  Mumbai  Patna     2h 25m   Non Stop          11:20
# 2     Air India  Mumbai  Patna     2h 40m   Non Stop          11:15
# 3      Go First  Mumbai  Patna     5h 50m     1 Stop          05:45
# 4      Go First  Mumbai  Patna     6h 40m     1 Stop          05:50
# ..          ...     ...    ...        ...        ...            ...
# 97      Vistara  Mumbai  Patna    11h 30m  2 Stop(s)          06:35
# 98      Vistara  Mumbai  Patna    11h 05m  2 Stop(s)          07:00
# 99      Vistara  Mumbai  Patna    11h 05m  2 Stop(s)          07:00
# 100     Vistara  Mumbai  Patna    12h 05m  2 Stop(s)          06:00
# 101     Vistara  Mumbai  Patna    12h 05m  2 Stop(s)          06:00
#
#     Arrived Time   Price Date Of Journey
# 0          20:25   6,677     09-jan-2023
# 1          13:45   6,677     09-jan-2023
# ...

# %%
160+150+62+66+67+68+90+90+88+114+112+11+160+163+167+141+141+137+135+132+137+134+104+104+102
# Out:
# 2835

# %%
driver.close()

# %% [markdown]
# # Next Data

# %%
#Lets Scrape Next Data
#First Connect to web driver 

driver = webdriver.Edge(r"D:\edgedriver_win64\msedgedriver.exe")
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="941a2ae14eec103c15c686050cfd47ef")>

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=JAI&destinationCountry=IN&flexi=0&flight_depart_date=07%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=952903898801&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"07-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_28')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 1       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 2         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 3         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 4   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          07:30
# 5       SpiceJet  New Delhi  Jaipur     1h 10m   Non Stop          20:10
# 6   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          19:30
# 7         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          20:30
# 8         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          07:45
# 9        Vistara  New Delhi  Jaipur    13h 50m     1 Stop          05:45
# 10       Vistara  New Delhi  Jaipur     7h 55m     1 Stop          11:40
# 11       Vistara  New Delhi  Jaipur     9h 15m     1 Stop          10:20
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"08-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_29')

# %%
Flight_Prediction4
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 1       Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 2         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 3       SpiceJet  New Delhi  Jaipur     1h 10m   Non Stop          20:10
# 4         IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 5   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          06:50
# 6   Alliance Air  New Delhi  Jaipur     1h 00m   Non Stop          19:30
# 7         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          20:30
# 8         IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          07:45
# 9      Air India  New Delhi  Jaipur    28h 15m     1 Stop          09:00
# 10     Air India  New Delhi  Jaipur    14h 45m     1 Stop          22:30
# 11     Air India  New Delhi  Jaipur    15h 55m     1 Stop          21:20
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"09-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_29')

# %%
Flight_Prediction4
# Out:
#    Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0     Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 1     Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 2       IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 3     SpiceJet  New Delhi  Jaipur     1h 10m   Non Stop          20:10
# 4       IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# ..         ...        ...     ...        ...        ...            ...
# 63     Vistara  New Delhi  Jaipur    20h 00m  2 Stop(s)          17:35
# 64     Vistara  New Delhi  Jaipur    26h 00m  2 Stop(s)          17:35
# 65     Vistara  New Delhi  Jaipur    20h 00m  2 Stop(s)          17:35
# 66     Vistara  New Delhi  Jaipur    27h 15m  2 Stop(s)          10:20
# 67     Vistara  New Delhi  Jaipur    12h 40m  2 Stop(s)          06:55
#
#       Arrived Time   Price Date Of Journey
# 0            06:05   1,767     09-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 69

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"10-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_30')

# %%
Flight_Prediction4
# Out:
#    Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0     Air Asia  New Delhi  Jaipur     1h 10m   Non Stop          04:55
# 1     Air Asia  New Delhi  Jaipur     1h 00m   Non Stop          20:25
# 2       IndiGo  New Delhi  Jaipur     0h 55m   Non Stop          22:45
# 3       IndiGo  New Delhi  Jaipur     1h 00m   Non Stop          05:10
# 4     SpiceJet  New Delhi  Jaipur     1h 10m   Non Stop          20:10
# ..         ...        ...     ...        ...        ...            ...
# 64     Vistara  New Delhi  Jaipur    25h 50m     1 Stop          17:45
# 65     Vistara  New Delhi  Jaipur     6h 05m     1 Stop          07:30
# 66     Vistara  New Delhi  Jaipur    12h 05m     1 Stop          07:30
# 67     Vistara  New Delhi  Jaipur    24h 55m  2 Stop(s)          18:40
# 68     Vistara  New Delhi  Jaipur    32h 25m  2 Stop(s)          11:10
#
#       Arrived Time   Price Date Of Journey
# 0            06:05   1,767     10-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=07%2F01%2F2023&hb=0&noOfSegments=1&origin=IDR&originCountry=IN&type=O&unique=1152161030173&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"07-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_31')

# %%
Flight_Prediction4
# Out:
#    Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Indore  New Delhi     1h 25m   Non Stop          07:20
# 1      Vistara  Indore  New Delhi     1h 15m   Non Stop          08:10
# 2       IndiGo  Indore  New Delhi     1h 35m   Non Stop          22:50
# 3       IndiGo  Indore  New Delhi     1h 25m   Non Stop          18:50
# 4       IndiGo  Indore  New Delhi     1h 30m   Non Stop          11:30
# ..         ...     ...        ...        ...        ...            ...
# 62      IndiGo  Indore  New Delhi     5h 35m     1 Stop          07:50
# 63   Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
# 64   Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
# 65     Vistara  Indore  New Delhi    17h 40m  2 Stop(s)          15:40
# 66     Vistara  Indore  New Delhi     5h 00m     1 Stop          15:40
#
#       Arrived Time   Price Date Of Journey
# 0            08:45   4,478     07-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 66
# 66
# 66
# 66
# 66
# 66
# 66
# 66

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"08-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_32')

# %%
Flight_Prediction4
# Out:
#    Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Indore  New Delhi     1h 25m   Non Stop          07:20
# 1      Vistara  Indore  New Delhi     1h 15m   Non Stop          08:10
# 2       IndiGo  Indore  New Delhi     1h 30m   Non Stop          11:30
# 3       IndiGo  Indore  New Delhi     9h 10m     1 Stop          08:05
# 4       IndiGo  Indore  New Delhi     5h 55m     1 Stop          17:00
# ..         ...     ...        ...        ...        ...            ...
# 61     Vistara  Indore  New Delhi     8h 05m  2 Stop(s)          15:40
# 62     Vistara  Indore  New Delhi     8h 25m  2 Stop(s)          15:40
# 63   Air India  Indore  New Delhi    16h 20m  2 Stop(s)          16:35
# 64     Vistara  Indore  New Delhi     8h 30m     1 Stop          15:40
# 65     Vistara  Indore  New Delhi    17h 40m  2 Stop(s)          15:40
#
#       Arrived Time   Price Date Of Journey
# 0            08:45   4,478     08-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 62
# 62
# 62
# 62
# 62
# 62
# 62
# 62

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"09-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_33')

# %%
Flight_Prediction4
# Out:
#    Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Indore  New Delhi     1h 25m   Non Stop          07:20
# 1      Vistara  Indore  New Delhi     1h 15m   Non Stop          08:10
# 2       IndiGo  Indore  New Delhi     1h 35m   Non Stop          22:50
# 3       IndiGo  Indore  New Delhi     1h 30m   Non Stop          11:30
# 4       IndiGo  Indore  New Delhi    11h 40m     1 Stop          21:35
# ..         ...     ...        ...        ...        ...            ...
# 57      IndiGo  Indore  New Delhi     5h 05m     1 Stop          06:05
# 58     Vistara  Indore  New Delhi     1h 35m   Non Stop          20:55
# 59     Vistara  Indore  New Delhi     8h 25m  2 Stop(s)          15:40
# 60   Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
# 61   Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
#
#       Arrived Time   Price Date Of Journey
# 0            08:45   5,527     09-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"10-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_34')

# %%
Flight_Prediction4
# Out:
#      Flight Name    From         To Time Taken    Stopage Departure Time  \
# 0         IndiGo  Indore  New Delhi     1h 30m   Non Stop          11:30
# 1         IndiGo  Indore  New Delhi     1h 25m   Non Stop          07:20
# 2   Alliance Air  Indore  New Delhi     4h 00m     1 Stop          16:00
# 3         IndiGo  Indore  New Delhi     1h 35m   Non Stop          22:50
# 4        Vistara  Indore  New Delhi     1h 15m   Non Stop          08:10
# ..           ...     ...        ...        ...        ...            ...
# 63       Vistara  Indore  New Delhi     6h 15m     1 Stop          15:40
# 64       Vistara  Indore  New Delhi     8h 25m  2 Stop(s)          15:40
# 65     Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
# 66     Air India  Indore  New Delhi    16h 40m  2 Stop(s)          16:35
# 67       Vistara  Indore  New Delhi    17h 40m  2 Stop(s)          15:40
#
#       Arrived Time   Price Date Of Journey
# 0            13:00   4,478     10-jan-2023
# ...

# %% [markdown]
# # NEXT DATA

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=RPR&destinationCountry=IN&flexi=0&flight_depart_date=07%2F01%2F2023&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=222830016237&version=1.1&viewName=normal'
driver.get(url)

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"07-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_35')

# %%
Flight_Prediction4
# Out:
#    Flight Name     From      To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          05:25
# 1       IndiGo  Kolkata  Raipur    11h 45m     1 Stop          23:15
# 2       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          07:35
# 3       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          15:15
# 4       IndiGo  Kolkata  Raipur     2h 20m   Non Stop          17:10
# 5       IndiGo  Kolkata  Raipur     8h 45m     1 Stop          11:05
# 6       IndiGo  Kolkata  Raipur     6h 45m     1 Stop          11:05
# 7       IndiGo  Kolkata  Raipur     8h 50m     1 Stop          09:00
# 8      Vistara  Kolkata  Raipur    26h 30m     1 Stop          07:10
# 9      Vistara  Kolkata  Raipur    12h 30m     1 Stop          07:10
# 10      IndiGo  Kolkata  Raipur    10h 50m     1 Stop          09:00
# 11     Vistara  Kolkata  Raipur    13h 15m     1 Stop          20:25
# 12     Vistara  Kolkata  Raipur    23h 15m     1 Stop          20:25
# ...

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=RPR&destinationCountry=IN&flexi=0&flight_depart_date=07%2F01%2F2023&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=222830016237&version=1.1&viewName=normal'
driver.get(url)

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
print(len(Flight_Name))
print(len(From))
print(len(To))
print(len(Time_Taken))
print(len(Stopage))
print(len(Price))
print(len(Departure_Time))
print(len(Arrived_Time))
# Out:
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"08-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_36')

# %%
Flight_Prediction4
# Out:
#    Flight Name     From      To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          07:35
# 1       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          15:15
# 2       IndiGo  Kolkata  Raipur     2h 20m   Non Stop          17:10
# 3       IndiGo  Kolkata  Raipur     7h 00m     1 Stop          06:00
# 4       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          05:25
# 5       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          07:25
# 6      Vistara  Kolkata  Raipur    12h 30m     1 Stop          07:10
# 7      Vistara  Kolkata  Raipur    23h 15m     1 Stop          20:25
# 8      Vistara  Kolkata  Raipur    13h 15m     1 Stop          20:25
# 9      Vistara  Kolkata  Raipur    26h 30m     1 Stop          07:10
# 10      IndiGo  Kolkata  Raipur    11h 45m     1 Stop          23:15
# 11     Vistara  Kolkata  Raipur     9h 25m     1 Stop          10:15
# 12     Vistara  Kolkata  Raipur    24h 55m     1 Stop          18:45
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"09-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_37')

# %%
Flight_Prediction4
# Out:
#    Flight Name     From      To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Kolkata  Raipur     2h 20m   Non Stop          17:10
# 1       IndiGo  Kolkata  Raipur     9h 00m     1 Stop          08:50
# 2       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          15:15
# 3       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          07:35
# 4       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          05:25
# 5       IndiGo  Kolkata  Raipur     7h 00m     1 Stop          06:00
# 6       IndiGo  Kolkata  Raipur     5h 55m     1 Stop          13:55
# 7       IndiGo  Kolkata  Raipur    11h 00m     1 Stop          08:50
# 8       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          07:25
# 9      Vistara  Kolkata  Raipur    13h 15m     1 Stop          20:25
# 10     Vistara  Kolkata  Raipur    14h 55m     1 Stop          18:45
# 11     Vistara  Kolkata  Raipur    23h 15m     1 Stop          20:25
# 12     Vistara  Kolkata  Raipur    24h 55m     1 Stop          18:45
# ...

# %% [markdown]
# # NEXT DATA

# %%
# Scraping details of product for which you want
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"10-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_37')

# %%
Flight_Prediction4
# Out:
#    Flight Name     From      To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Kolkata  Raipur     8h 20m     1 Stop          05:25
# 1       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          07:35
# 2       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          15:15
# 3       IndiGo  Kolkata  Raipur     2h 20m   Non Stop          17:10
# 4       IndiGo  Kolkata  Raipur     5h 55m     1 Stop          13:55
# 5       IndiGo  Kolkata  Raipur    11h 00m     1 Stop          08:50
# 6       IndiGo  Kolkata  Raipur     9h 00m     1 Stop          08:50
# 7      Vistara  Kolkata  Raipur    13h 15m     1 Stop          20:25
# 8      Vistara  Kolkata  Raipur    14h 55m     1 Stop          18:45
# 9      Vistara  Kolkata  Raipur    18h 20m     1 Stop          15:20
# 10     Vistara  Kolkata  Raipur    23h 15m     1 Stop          20:25
# 11     Vistara  Kolkata  Raipur    23h 25m     1 Stop          10:15
# 12     Vistara  Kolkata  Raipur    26h 30m     1 Stop          07:10
# ...

# %% [markdown]
# # NEXT DATA

# %%
Flight_Name=[]
From=[]
To=[]
Time_Taken=[]
Stopage=[]
Price=[]
Departure_Time=[]
Arrived_Time=[]

# %%
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//span[@class='i-b text ellipsis']")
    for i in name:
        Flight_Name.append(i.text)
except NoSuchElementException:
    Flight_Name.append('Nan')
    
# scraping  From Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-12 bold du mb-2']")
    for i in name:
        Time_Taken.append(i.text)
except NoSuchElementException:
    Time_Taken.append('-')
    
# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']//span[1]")
    for i in name:
        Stopage.append(i.text)
except NoSuchElementException:
    Stopage.append('-')
    

try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    

# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//div[@class='i-b pr']")
    for i in name:
        Departure_Time.append(i.text)
except NoSuchElementException:
    Departure_Time.append('-')
    


# scraping  Flight Name
try:
    name = driver.find_elements(By.XPATH,"//p[@class='bold fs-15 mb-2 pr time']")
    for i in name:
        Arrived_Time.append(i.text)
except NoSuchElementException:
    Arrived_Time.append('-')

# %%
#Lets make dataframe
import pandas as pd
Flight_Prediction4=pd.DataFrame({"Flight Name":Flight_Name,"From":From,"To":To,"Time Taken":Time_Taken,"Stopage":Stopage,"Departure Time":Departure_Time,"Arrived Time":Arrived_Time,"Price":Price,"Date Of Journey":"11-jan-2023"})

# %%
Flight_Prediction4.to_csv('Flight_Prediction_38')

# %%
Flight_Prediction4
# Out:
#    Flight Name     From      To Time Taken    Stopage Departure Time  \
# 0       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          07:35
# 1       IndiGo  Kolkata  Raipur     1h 35m   Non Stop          15:15
# 2       IndiGo  Kolkata  Raipur     2h 20m   Non Stop          17:10
# 3       IndiGo  Kolkata  Raipur     8h 20m     1 Stop          05:25
# 4       IndiGo  Kolkata  Raipur     5h 35m     1 Stop          07:25
# 5       IndiGo  Kolkata  Raipur     7h 00m     1 Stop          06:00
# 6       IndiGo  Kolkata  Raipur    11h 00m     1 Stop          08:50
# 7       IndiGo  Kolkata  Raipur     5h 55m     1 Stop          13:55
# 8       IndiGo  Kolkata  Raipur     9h 00m     1 Stop          08:50
# 9      Vistara  Kolkata  Raipur    13h 15m     1 Stop          20:25
# 10     Vistara  Kolkata  Raipur    14h 55m     1 Stop          18:45
# 11     Vistara  Kolkata  Raipur    18h 20m     1 Stop          15:20
# 12     Vistara  Kolkata  Raipur    23h 15m     1 Stop          20:25
# ...

# %%
# Ne
