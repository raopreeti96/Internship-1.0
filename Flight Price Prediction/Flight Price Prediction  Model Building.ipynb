# %%
#Lets import necessory Libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Lets Load the Dataset
data=pd.read_csv("Flight_Prediction_CSV_ScrapData")
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Flight Name       From      To Time Taken Stopage  \
# 0             0           0    Go First  New Delhi  Mumbai    14h 20m  1 Stop
# 1             1           1    Go First  New Delhi  Mumbai     8h 40m  1 Stop
# 2             2           2    Go First  New Delhi  Mumbai     8h 05m  1 Stop
# 3             3           3    Go First  New Delhi  Mumbai     5h 15m  1 Stop
# 4             4           4    Go First  New Delhi  Mumbai     6h 00m  1 Stop
#
#   Departure Time    Arrived Time  Price Date Of Journey
# 0          18:00           08:00  6,454     04-jan-2023
# 1          04:55           09:15  6,632     04-jan-2023
# 2          22:00  10:30\n+ 1 day  6,755     04-jan-2023
# 3          05:00           16:20  6,873     04-jan-2023
# 4          10:40           22:05  6,873     04-jan-2023

# %%
#Lets check the shape of the dataset
data.shape
# Out:
# (3731, 11)

# %% [markdown]
# So, Here we 3731 Rows and 11 Columns .

# %%
#Lets check for insa
data.isna().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# Flight Name        0
# From               0
# To                 0
# Time Taken         0
# Stopage            0
# Departure Time     0
# Arrived Time       0
# Price              0
# Date Of Journey    0
# dtype: int64

# %%
data.loc[data['Flight Name']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['From']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['To']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Time Taken']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Stopage']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Departure Time']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Arrived Time']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Price']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %%
data.loc[data['Date Of Journey']=="-"]#loc method is use to access to use the group of data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Flight Name, From, To, Time Taken, Stopage, Departure Time, Arrived Time, Price, Date Of Journey]
# Index: []

# %% [markdown]
# So, here we dont have any nulls we are good to proceed but we have to delete some unncessory columns Unnamed,
#
# Lets Move foreword and delete this .

# %%
data.drop(columns=["Unnamed: 0","Unnamed: 0.1"],inplace=True)

# %%
#Lets see the dataset
data
# Out:
#      Flight Name       From      To Time Taken    Stopage Departure Time  \
# 0       Go First  New Delhi  Mumbai    14h 20m     1 Stop          18:00
# 1       Go First  New Delhi  Mumbai     8h 40m     1 Stop          04:55
# 2       Go First  New Delhi  Mumbai     8h 05m     1 Stop          22:00
# 3       Go First  New Delhi  Mumbai     5h 15m     1 Stop          05:00
# 4       Go First  New Delhi  Mumbai     6h 00m     1 Stop          10:40
# ...          ...        ...     ...        ...        ...            ...
# 3726     Vistara    Kolkata  Raipur    16h 10m  2 Stop(s)          17:30
# 3727     Vistara    Kolkata  Raipur    16h 10m  2 Stop(s)          17:30
# 3728   Air India    Kolkata  Raipur    16h 45m  2 Stop(s)          19:00
# 3729     Vistara    Kolkata  Raipur    23h 00m  2 Stop(s)          20:40
# 3730     Vistara    Kolkata  Raipur     9h 20m  2 Stop(s)          10:20
#
#         Arrived Time   Price Date Of Journey
# 0              08:00   6,454     04-jan-2023
# ...

# %%
#lets check the data of the datatype
data.dtypes
# Out:
# Flight Name        object
# From               object
# To                 object
# Time Taken         object
# Stopage            object
# Departure Time     object
# Arrived Time       object
# Price              object
# Date Of Journey    object
# dtype: object

# %% [markdown]
# All columns in Object .. We have to predict Price .. Lets convet in float values .

# %%
# Let's replace "," sign by empty space
data['Price'] = data['Price'].str.replace(',','')
# Let's convert data type of Price column to float
data['Price'] = data['Price'].astype('float')

# %%
data.dtypes
# Out:
# Flight Name         object
# From                object
# To                  object
# Time Taken          object
# Stopage             object
# Departure Time      object
# Arrived Time        object
# Price              float64
# Date Of Journey     object
# dtype: object

# %%
data.head()
# Out:
#   Flight Name       From      To Time Taken Stopage Departure Time  \
# 0    Go First  New Delhi  Mumbai    14h 20m  1 Stop          18:00
# 1    Go First  New Delhi  Mumbai     8h 40m  1 Stop          04:55
# 2    Go First  New Delhi  Mumbai     8h 05m  1 Stop          22:00
# 3    Go First  New Delhi  Mumbai     5h 15m  1 Stop          05:00
# 4    Go First  New Delhi  Mumbai     6h 00m  1 Stop          10:40
#
#      Arrived Time   Price Date Of Journey
# 0           08:00  6454.0     04-jan-2023
# 1           09:15  6632.0     04-jan-2023
# 2  10:30\n+ 1 day  6755.0     04-jan-2023
# 3           16:20  6873.0     04-jan-2023
# 4           22:05  6873.0     04-jan-2023

# %%
#Lets check the info of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3731 entries, 0 to 3730
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Flight Name      3731 non-null   object
#  1   From             3731 non-null   object
#  2   To               3731 non-null   object
#  3   Time Taken       3731 non-null   object
#  4   Stopage          3731 non-null   object
#  5   Departure Time   3731 non-null   object
#  6   Arrived Time     3731 non-null   object
#  7   Price            3731 non-null   float64
#  8   Date Of Journey  3731 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 262.5+ KB

# %%
data.head()
# Out:
#   Flight Name       From      To Time Taken Stopage Departure Time  \
# 0    Go First  New Delhi  Mumbai    14h 20m  1 Stop          18:00
# 1    Go First  New Delhi  Mumbai     8h 40m  1 Stop          04:55
# 2    Go First  New Delhi  Mumbai     8h 05m  1 Stop          22:00
# 3    Go First  New Delhi  Mumbai     5h 15m  1 Stop          05:00
# 4    Go First  New Delhi  Mumbai     6h 00m  1 Stop          10:40
#
#      Arrived Time   Price Date Of Journey
# 0           08:00  6454.0     04-jan-2023
# 1           09:15  6632.0     04-jan-2023
# 2  10:30\n+ 1 day  6755.0     04-jan-2023
# 3           16:20  6873.0     04-jan-2023
# 4           22:05  6873.0     04-jan-2023

# %%
#lets Convert in Date Time 
data['Date Of Journey'] = pd.to_datetime(data['Date Of Journey'])

# %%
data.dtypes
# Out:
# Flight Name                object
# From                       object
# To                         object
# Time Taken                 object
# Stopage                    object
# Departure Time             object
# Arrived Time               object
# Price                     float64
# Date Of Journey    datetime64[ns]
# dtype: object

# %%
#Extracting Day from Date_of_journey column
data['Day'] = pd.to_datetime(data['Date Of Journey'],format="%d/%m/%Y").dt.day

#Extracting Month from Date_of_journey column
data['Month'] = pd.to_datetime(data['Date Of Journey'], format="%d/%m/%Y").dt.month

#Extracting Year from Date_of_journey column
data['Year'] = pd.to_datetime(data['Date Of Journey'], format="%d/%m/%Y").dt.year

# %%
data.head()
# Out:
#   Flight Name       From      To Time Taken Stopage Departure Time  \
# 0    Go First  New Delhi  Mumbai    14h 20m  1 Stop          18:00
# 1    Go First  New Delhi  Mumbai     8h 40m  1 Stop          04:55
# 2    Go First  New Delhi  Mumbai     8h 05m  1 Stop          22:00
# 3    Go First  New Delhi  Mumbai     5h 15m  1 Stop          05:00
# 4    Go First  New Delhi  Mumbai     6h 00m  1 Stop          10:40
#
#      Arrived Time   Price Date Of Journey  Day  Month  Year
# 0           08:00  6454.0      2023-01-04    4      1  2023
# 1           09:15  6632.0      2023-01-04    4      1  2023
# 2  10:30\n+ 1 day  6755.0      2023-01-04    4      1  2023
# 3           16:20  6873.0      2023-01-04    4      1  2023
# 4           22:05  6873.0      2023-01-04    4      1  2023

# %%
data.drop(columns='Date Of Journey',inplace=True)

# %%
data.head()
# Out:
#   Flight Name       From      To Time Taken Stopage Departure Time  \
# 0    Go First  New Delhi  Mumbai    14h 20m  1 Stop          18:00
# 1    Go First  New Delhi  Mumbai     8h 40m  1 Stop          04:55
# 2    Go First  New Delhi  Mumbai     8h 05m  1 Stop          22:00
# 3    Go First  New Delhi  Mumbai     5h 15m  1 Stop          05:00
# 4    Go First  New Delhi  Mumbai     6h 00m  1 Stop          10:40
#
#      Arrived Time   Price  Day  Month  Year
# 0           08:00  6454.0    4      1  2023
# 1           09:15  6632.0    4      1  2023
# 2  10:30\n+ 1 day  6755.0    4      1  2023
# 3           16:20  6873.0    4      1  2023
# 4           22:05  6873.0    4      1  2023

# %%
data['Departure Time'].dtypes

data['Departure Time'] = pd.to_datetime(data['Departure Time'])

# %%
# Extract Hour from Time

data['Dep_hour'] = data['Departure Time'].dt.hour

data['Dep_hour'].head()
# Out:
# 0    18
# 1     4
# 2    22
# 3     5
# 4    10
# Name: Dep_hour, dtype: int64

# %%
# Extract Min from Time

data['Dep_min'] = data['Departure Time'].dt.minute

data['Dep_min'].head()
# Out:
# 0     0
# 1    55
# 2     0
# 3     0
# 4    40
# Name: Dep_min, dtype: int64

# %%
data.drop('Departure Time',inplace=True,axis=1)

# %%
def get_duration(x):
    x=x.split(' ')
    hours=0
    mins=0
    if len(x)==1:
        x=x[0]
        if x[-1]=='h':
            hours=int(x[:-1])
        else:
            mins=int(x[:-1])
    else:
        hours=int(x[0][:-1])
        mins=int(x[1][:-1])
    return hours,mins
data['Duration_hours']=data['Time Taken'].apply(lambda x:get_duration(x)[0])
data['Duration_mins']=data['Time Taken'].apply(lambda x:get_duration(x)[1])
data.drop(["Time Taken"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %%
# Let's replace "," sign by empty space
data['Arrived Time'] = data["Arrived Time"].str.replace('\n+ 1 day','')

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %% [markdown]
# # Visualization of the Data.

# %%
sns.countplot(x='Flight Name',data=data)
# Out:
# <AxesSubplot:xlabel='Flight Name', ylabel='count'>

# %%
sns.countplot(x='From',data=data)
# Out:
# <AxesSubplot:xlabel='From', ylabel='count'>

# %%
plt.figure(figsize=(5,6),facecolor='red')
sns.countplot(x='To',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Stopage',data=data)
# Out:
# <AxesSubplot:xlabel='Stopage', ylabel='count'>

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %%
sns.barplot(x='Dep_hour',y='Dep_min',data=data)
# Out:
# <AxesSubplot:xlabel='Dep_hour', ylabel='Dep_min'>

# %%
sns.relplot(x='Dep_hour',y='Dep_min',data=data)

# %%
sns.relplot(x='Dep_hour',y='Price',data=data)

# %%
sns.relplot(x='Dep_min',y='Price',data=data)

# %%
sns.relplot(x='Duration_hours',y='Price',data=data)

# %%
sns.relplot(x='Duration_mins',y='Price',data=data)

# %%
plt.figure(figsize=(20,15))
sns.relplot(x='Flight Name',y='Price',data=data)
plt.xticks(rotation='90')
plt.show()

# %%
sns.relplot(x='Arrived Time',y='Price',data=data)

# %%
data.head(2)
# Out:
#   Flight Name       From      To Stopage Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop        08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop        09:15  6632.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40

# %%
sns.relplot(x='From',y='Price',data=data)

# %%
plt.figure(figsize=(20,15))
sns.relplot(x='To',y='Price',data=data)
plt.xticks(rotation='70')
plt.show()

# %%
sns.relplot(x='Stopage',y='Price',data=data)

# %%
sns.relplot(x='Arrived Time',y='Price',data=data)

# %%
sns.distplot(data['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# Looks Like Normal Distribution .But its is Right Skewed.

# %%
sns.distplot(data['Day'])
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Density'>

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %%
sns.distplot(data['Dep_hour'])
# Out:
# <AxesSubplot:xlabel='Dep_hour', ylabel='Density'>

# %%
sns.distplot(data['Dep_min'])
# Out:
# <AxesSubplot:xlabel='Dep_min', ylabel='Density'>

# %%
sns.distplot(data['Duration_hours'])
# Out:
# <AxesSubplot:xlabel='Duration_hours', ylabel='Density'>

# %%
sns.distplot(data['Duration_mins'])
# Out:
# <AxesSubplot:xlabel='Duration_mins', ylabel='Density'>

# %%
data.head()
# Out:
#   Flight Name       From      To Stopage    Arrived Time   Price  Day  Month  \
# 0    Go First  New Delhi  Mumbai  1 Stop           08:00  6454.0    4      1
# 1    Go First  New Delhi  Mumbai  1 Stop           09:15  6632.0    4      1
# 2    Go First  New Delhi  Mumbai  1 Stop  10:30\n+ 1 day  6755.0    4      1
# 3    Go First  New Delhi  Mumbai  1 Stop           16:20  6873.0    4      1
# 4    Go First  New Delhi  Mumbai  1 Stop           22:05  6873.0    4      1
#
#    Year  Dep_hour  Dep_min  Duration_hours  Duration_mins
# 0  2023        18        0              14             20
# 1  2023         4       55               8             40
# 2  2023        22        0               8              5
# 3  2023         5        0               5             15
# 4  2023        10       40               6              0

# %%
sns.countplot(x='From',hue='To',data=data)
# Out:
# <AxesSubplot:xlabel='From', ylabel='count'>

# %% [markdown]
# From the domain knowledge we dont think there is a outliers . so we dont need to treat them..

# %% [markdown]
# # Data PreProcessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#checking categorical columns
cat_col=[]
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Flight Name', 'From', 'To', 'Stopage', 'Arrived Time']

# %%
le=LabelEncoder()
data[cat_col]= data[cat_col].apply(le.fit_transform)
data
# Out:
#       Flight Name  From  To  Stopage  Arrived Time    Price  Day  Month  Year  \
# 0               3     3   6        0            70   6454.0    4      1  2023
# 1               3     3   6        0            95   6632.0    4      1  2023
# 2               3     3   6        0           123   6755.0    4      1  2023
# 3               3     3   6        0           215   6873.0    4      1  2023
# 4               3     3   6        0           311   6873.0    4      1  2023
# ...           ...   ...  ..      ...           ...      ...  ...    ...   ...
# 3726            6     1   9        1           105  22674.0   11      1  2023
# 3727            6     1   9        1           105  22989.0   11      1  2023
# 3728            1     1   9        1           148  23307.0   11      1  2023
# 3729            6     1   9        1           275  27716.0   11      1  2023
# 3730            6     1   9        1           274  28241.0   11      1  2023
#
# ...

# %%
# Out:
#       Duration_hours       Day
# 0           0.394375  1.864243
# 1           0.369929  1.864243
# 2           0.369929  1.864243
# 3           0.752082  1.864243
# 4           0.624698  1.864243
# ...              ...       ...
# 3726        0.649143  1.431529
# 3727        0.649143  1.431529
# 3728        0.649143  1.431529
# 3729        1.540832  1.431529
# 3730        0.242545  1.431529
#
# [3731 rows x 2 columns]

# %%
# Identifying the outliers using boxplot
plt.figure(figsize=(15,10),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=20:
        ax=plt.subplot(3,7,plotnumber)
        sns.boxplot(data[column],color="darkorange")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we dont Consider outliers.

# %%
data.corr()
# Out:
#                 Flight Name      From        To   Stopage  Arrived Time  \
# Flight Name        1.000000 -0.062823  0.008622  0.010594      0.070172
# From              -0.062823  1.000000 -0.535736  0.087836      0.020834
# To                 0.008622 -0.535736  1.000000 -0.033817      0.047300
# Stopage            0.010594  0.087836 -0.033817  1.000000     -0.008857
# Arrived Time       0.070172  0.020834  0.047300 -0.008857      1.000000
# Price              0.133280 -0.033639  0.081252 -0.216720      0.118349
# Day               -0.061405 -0.051428  0.107706 -0.047261      0.013748
# Month                   NaN       NaN       NaN       NaN           NaN
# Year                    NaN       NaN       NaN       NaN           NaN
# Dep_hour          -0.012587  0.023931 -0.075185  0.014079     -0.051677
# Dep_min            0.216567 -0.071648  0.031035  0.057221     -0.003191
# Duration_hours    -0.004011 -0.037815  0.082008 -0.293599      0.022149
# ...

# %%
#Lest check correlation with target columns in sorted values
data.corr()['Price']
# Out:
# Flight Name       0.133280
# From             -0.033639
# To                0.081252
# Stopage          -0.216720
# Arrived Time      0.118349
# Price             1.000000
# Day               0.031227
# Month                  NaN
# Year                   NaN
# Dep_hour         -0.032077
# Dep_min           0.028057
# Duration_hours    0.302583
# Duration_mins     0.028010
# Name: Price, dtype: float64

# %%
data
# Out:
#       Flight Name  From  To  Stopage  Arrived Time    Price  Day  Month  Year  \
# 0               3     3   6        0            70   6454.0    4      1  2023
# 1               3     3   6        0            95   6632.0    4      1  2023
# 2               3     3   6        0           123   6755.0    4      1  2023
# 3               3     3   6        0           215   6873.0    4      1  2023
# 4               3     3   6        0           311   6873.0    4      1  2023
# ...           ...   ...  ..      ...           ...      ...  ...    ...   ...
# 3726            6     1   9        1           105  22674.0   11      1  2023
# 3727            6     1   9        1           105  22989.0   11      1  2023
# 3728            1     1   9        1           148  23307.0   11      1  2023
# 3729            6     1   9        1           275  27716.0   11      1  2023
# 3730            6     1   9        1           274  28241.0   11      1  2023
#
# ...

# %%
data.drop(columns='Month',inplace=True)

# %%
data.drop(columns='Year',inplace=True)

# %%
#Lest check correlation with target columns in sorted values
data.corr()['Price']
# Out:
# Flight Name       0.133280
# From             -0.033639
# To                0.081252
# Stopage          -0.216720
# Arrived Time      0.118349
# Price             1.000000
# Day               0.031227
# Dep_hour         -0.032077
# Dep_min           0.028057
# Duration_hours    0.302583
# Duration_mins     0.028010
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(22,7))
data.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(data.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# # Separate X AND Y

# %%
#Lets separate x and y
x=data.drop(columns='Price')

# %%
y=data['Price']

# %%
x.skew()
# Out:
# Flight Name      -0.287774
# From             -2.007421
# To                0.226459
# Stopage           1.257951
# Arrived Time     -0.325824
# Day               0.690139
# Dep_hour         -0.026815
# Dep_min          -0.092571
# Duration_hours    0.801417
# Duration_mins     0.042984
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

# %%
scaler = PowerTransformer()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Flight Name      From        To   Stopage  Arrived Time       Day  \
# 0       -0.273616  0.604732  0.885374 -0.652523     -1.291027 -2.323418
# 1       -0.273616  0.604732  0.885374 -0.652523     -1.015886 -2.323418
# 2       -0.273616  0.604732  0.885374 -0.652523     -0.712694 -2.323418
# 3       -0.273616  0.604732  0.885374 -0.652523      0.258961 -2.323418
# 4       -0.273616  0.604732  0.885374 -0.652523      1.246572 -2.323418
# ...           ...       ...       ...       ...           ...       ...
# 3706     1.148264 -1.965606  1.663652  1.409934     -0.907075  1.370744
# 3707     1.148264 -1.965606  1.663652  1.409934     -0.907075  1.370744
# 3708    -1.233458 -1.965606  1.663652  1.409934     -0.445418  1.370744
# 3709     1.148264 -1.965606  1.663652  1.409934      0.878663  1.370744
# 3710     1.148264 -1.965606  1.663652  1.409934      0.868405  1.370744
#
#       Dep_hour   Dep_min  Duration_hours  Duration_mins
# ...

# %%
x.skew()
# Out:
# Flight Name      -0.296786
# From             -1.125855
# To               -0.164947
# Stopage           0.888038
# Arrived Time     -0.377639
# Day               0.001136
# Dep_hour         -0.143963
# Dep_min          -0.464946
# Duration_hours   -0.046427
# Duration_mins    -0.337830
# dtype: float64

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
bestfeat = SelectKBest(score_func = f_classif, k = 'all')
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(35,'Score'))
# Out:
#           Feature       Score
# 1            From  121.815465
# 2              To   27.061700
# 3         Stopage   14.792317
# 0     Flight Name   10.309343
# 8  Duration_hours    6.519163
# 5             Day    5.613322
# 4    Arrived Time    2.106154
# 7         Dep_min    2.096523
# 6        Dep_hour    1.656454
# 9   Duration_mins    1.368080

# %% [markdown]
# # Lets Check With VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif
# Out:
#          Features       vif
# 0     Flight Name  1.074317
# 1            From  1.339264
# 2              To  1.363693
# 3         Stopage  1.121661
# 4    Arrived Time  1.011738
# 5             Day  1.028675
# 6        Dep_hour  1.029491
# 7         Dep_min  1.076479
# 8  Duration_hours  1.156171
# 9   Duration_mins  1.013426

# %% [markdown]
# There is no multicollinearity problem .
#
# We set threshold for +/ - 10

# %% [markdown]
# # Lets Build a Mode

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.7008441125220767 on Random State 51

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=51)

# %%
regressors = {
    
    'Random Forest' : RandomForestRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                     MAE          MSE         RMSE  R2-score
# Random Forest  1914.184  8584048.666  2929.854718     0.698

# %% [markdown]
# # Cross - Validation of the mode

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    isscore = cross_val_score(rf,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 17.94351140514547
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 3
# Cross validation score is:- 17.910966083774564
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 4
# Cross validation score is:- 5.309386462911711
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 5
# Cross validation score is:- 18.102905325271447
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 6
# Cross validation score is:- 15.383273318678196
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 7
# Cross validation score is:- 2.354174779157092
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 8
# Cross validation score is:- -4.977425729254098
# accuracy_score is:- 69.73881158189128
#
#
# At cv:- 9
# Cross validation score is:- -10.391251269845132
# accuracy_score is:- 69.73881158189128

# %% [markdown]
# # Gradient Boosting Regressor

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    gbr = GradientBoostingRegressor()
    gbr.fit(X_train, y_train)
    pred = gbr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

# %%
print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5988038326181511 on Random State 11

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=11)

# %%
regressors = {
    
    'Gradient Boost Regressor' : GradientBoostingRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                                MAE          MSE         RMSE  R2-score
# Gradient Boost Regressor  2320.759  9515189.817  3084.670131     0.599

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(2,10):
    isscore = cross_val_score(gbr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 28.038711879754892
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 3
# Cross validation score is:- 23.531702625783847
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 4
# Cross validation score is:- 23.955303805957584
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 5
# Cross validation score is:- 16.475577780689896
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 6
# Cross validation score is:- 19.523537985291263
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 7
# Cross validation score is:- 22.48834235647067
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 8
# Cross validation score is:- 13.353460370499237
# accuracy_score is:- 59.88038326181512
#
#
# At cv:- 9
# Cross validation score is:- -3.7527366398375026
# accuracy_score is:- 59.88038326181512

# %%
lsscore_selected = cross_val_score(gbr,x,y,cv=2).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.282244560787583
# The accuracy score is:  0.5988038326181512

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(0, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    xgb = XGBRegressor()
    xgb.fit(X_train, y_train)
    pred = xgb.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.7399724324407194 on Random State 377

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=377)

# %%
regressors = {
    
    'XG Boost Regressor' : XGBRegressor()
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                          MAE          MSE         RMSE  R2-score
# XG Boost Regressor  1898.666  7746539.282  2783.260549      0.74

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)

y_pred = xgb.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(10,20):
    isscore = cross_val_score(xgb,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 10
# Cross validation score is:- 20.95924978690699
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 11
# Cross validation score is:- 14.821429136470412
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 12
# Cross validation score is:- -6.176443088646004
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 13
# Cross validation score is:- -77.20334098424433
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 14
# Cross validation score is:- -29.394455140899733
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 15
# Cross validation score is:- -16.711181940025448
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 16
# Cross validation score is:- 1.8519129313839124
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 17
# Cross validation score is:- -5.549101182622205
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 18
# Cross validation score is:- 11.49712616224192
# accuracy_score is:- 73.99724324407194
#
#
# At cv:- 19
# ...

# %%
from sklearn.model_selection import cross_val_score
lsscore_selected = cross_val_score(xgb,x,y,cv=13).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  -0.7720334098424433
# The accuracy score is:  0.7399724324407194

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import cross_val_score
lsscore_selected = cross_val_score(xgb,x,y,cv=13).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  -0.7720334098424433
# The accuracy score is:  0.7399724324407194

# %%
xgb = XGBRegressor()

# %%
parameters = {'n_estimators' : [100,200 ],
              
             'max_depth':range(4,8),
             'learning_rate':[0.1,0.3],
          'max_leaves':[1,5]}

# %%
grd = GridSearchCV(xgb,param_grid = parameters)
grd.fit(X_train,y_train)

print('Best Params ',grd.best_params_)
# Out:
# Best Params  {'learning_rate': 0.1, 'max_depth': 7, 'max_leaves': 1, 'n_estimators': 100}

# %%
gbr = XGBRegressor(learning_rate= 0.1, max_depth= 8, max_leaves= 9, n_estimators= 100)

gbr.fit(X_train,y_train)

pred = gbr.predict(X_test)

r2_score(y_test,pred)
# Out:
# 0.7609577385169183

# %% [markdown]
# # Plot Actual VS Predicted

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred)
plt.plot(y_test,y_test)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %%
import pickle
filename=('Flight Price Prediction  Model Building')
pickle.dump(gbr,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Flight Price Prediction  Model Building','rb'))
result=loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 76.09577385169183

# %%
conclusion=pd.DataFrame([loaded_model.predict(X_train)[:],pred[:]],index=['predicted','original'])

# %%
conclusion
# Out:
#                    0             1            2             3     \
# predicted  15415.893555  16394.789062  24433.68750  15912.749023
# original   10437.827148  12173.937500  13734.18457  15301.952148
#
#                    4             5             6             7     \
# predicted   7690.986328  11879.240234  11593.159180  15957.405273
# original   10608.871094  11858.936523  12408.640625  13422.389648
#
#                    8             9     ...          2958          2959  \
# predicted  11361.507812  15169.213867  ...  14241.567383  15439.677734
# original   12387.208984  11513.309570  ...           NaN           NaN
#
#                   2960      2961          2962         2963          2964  \
# predicted  6351.724609  14862.25  12918.273438  5847.021484  10756.166992
# original           NaN       NaN           NaN          NaN           NaN
#
#                   2965          2966         2967
# predicted  9833.045898  20416.845703  7509.885742
# ...

# %%
#Student of DataTrained 
#Student of Data Science - Saurav
#Date - 10-01-2023
#Time -> 11:23
