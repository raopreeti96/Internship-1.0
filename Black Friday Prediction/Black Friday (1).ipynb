# %%
#Lets import 
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\saura\OneDrive\Desktop\blackFriday_train.csv")
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#Lets check for shape of the dataset
data.shape
# Out:
# (550068, 12)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
#Check for Nan Value
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# Here  I decided to take my all nan and fill some number so i get exact info about my dataset. then after my visualization i will take decision which is important fillna Or drop na

# %%
#Lets check for datatype
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
#Lets check the info of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
#Lets Describe the dataset
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
#Lets Describe the dataset
data.describe(include='O')
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      550068  550068  550068        550068                     550068
# unique       3631       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq         1880  414259  219587        231173                     193821

# %% [markdown]
# # EDA
#
# # Univariate

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Lets plot Gender 
sns.countplot(x='Gender',data=data)
plt.show()
print(data['Gender'].value_counts())
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %% [markdown]
# So, Here we can see that Male is More in Count and Female are Less

# %% [markdown]
# M    414259
# F    135809

# %%
#Lets plot Occupation
sns.countplot(data['Occupation'])
plt.show()
print(data['Occupation'].value_counts())
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %% [markdown]
# So, Here Maximum People Occupied with Occupation - 4 then 0 then 7 then 1 then 17 then 20 then 20 then 12 and so on.
#
# Least People Occupied with Occupation - 8 then 9 then 18 then 18 then 13 then 19 then 11 and so on

# %%
#Lets plot Age
sns.countplot(x='Age',data=data)
plt.show()
data.Age.value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %% [markdown]
# Here , We can see that Maximum People Order Place From 26-35 Age Groop then 36-45 then 18-25. ,  and 18-25 and Least People From 0-17 then 55+ then 51-55 then 46-50.

# %%
#LETS PLOT City_Categor
sns.countplot(x='City_Category',data=data)
plt.show()
print(data['City_Category'].value_counts())
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %% [markdown]
# Here we can see that  maximum order place from City B then C and then A .

# %%
#Lets plot Stay_In_Current_City_Years
sns.countplot(x='Stay_In_Current_City_Years',data=data)
plt.show()
data.Stay_In_Current_City_Years.value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %% [markdown]
# Here , We can see that Which People Stay from 1 Year who are shoping more and then Who live from 2 year they are most order and then who live from 3 and then who live from more then 4 year and least order place from who live from less then 1 year.

# %%
#Lets plot Marital_Status
sns.countplot(x='Marital_Status',data=data)
plt.show()
data.Marital_Status.value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %% [markdown]
# Here , We can see Martial Status for 0-324731 and 1- 225337

# %%
#Lets plot Product_Category_1
sns.countplot(x='Product_Category_1',data=data)
plt.show()
data.Product_Category_1.value_counts()
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category_1, dtype: int64

# %% [markdown]
# Maximum ordered  Product is  1 , 5 , 8 ,11 , 2,6,3 and 4 and Least is Product - 9,17, 14 , 19 ,20, 18, 7, ,12 ,10,  13, 15 and 16.

# %%
#Lets plot Product_Category_2
sns.countplot(x='Product_Category_2',data=data)
plt.xticks(rotation=90)
plt.show()
data.Product_Category_2.value_counts()
# Out:
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %% [markdown]
# Here We, can see  that  product 8.0,14.0,2.0,16.0  is maximum sale in Product category 2 and least is 7.0 and 18,3.0,10.0,12.0 and 9.0

# %%
#Lets plot Product_Category_3
sns.countplot(x='Product_Category_3',data=data)
plt.xticks(rotation=90)
plt.show()
data.Product_Category_3.value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %% [markdown]
# So, Product 16.0,15.0,14.0,17.0,5.0,8.0, and 9.0 is Maximum sale in Product Category 3 and Least is  3.0,10.0,11.0,4.0,18.0 and  6.0

# %%
#Lets plot Purchase
sns.distplot(data['Purchase'])
plt.show()

# %% [markdown]
# Here , We can see that Purchase Column is not a normally distributed . So, Lets see fpr outliers.

# %%
#Lets plot Boxplot for Purchase
sns.boxplot(x=data['Purchase'])
plt.show()

# %% [markdown]
# So, Here we can see that we have outliers of . but we dont keep as outliers because some people also shooping for high price product. So we keep this ourliers.

# %% [markdown]
# # Bivaraite Analysis

# %%
#Lets plot Product Category 2 with Purchase

sns.barplot(x='Product_Category_2',y='Purchase',data=data,)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here , We can see that Product_Category_2 Maximum Price Product is , Product 10.0 then 2.0 then 6.0 then 3.0 then 15 and 16.
#
#
# Least Costly Product is, Product 7.0 then 12.0,then 14.0 then 11.0 So on..

# %%
#Lets plot Product Category 3 with Purchase

sns.barplot(x='Product_Category_3',y='Purchase',data=data,)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here , We can see that Product_Category_3 Maximum Price Product is , Product 3.0 then 10.0 then 14.0 then 6.0 then 8.0 and 15.0.
#
#
# Least Costly Product is, Product 12.0 then 4.0,then 14.0 then 9.0.0 So on..

# %%
#Lets plot Product Category 1 with Purchase
sns.barplot(x='Product_Category_1',y='Purchase',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here , We can see that Product_Category_1 Maximum Price Product is , Product 10.0 then 7.0 then 6.0 then 6.0 then 9.0 then 15.0 and 16 .
#
#
# Least Costly Product is, Product 19.0 then 20.0,then 13.0 then 12.0 then 4.0 then 18 then 11 and 5 .

# %%
#Lets plot Gender and Purchase
sns.barplot(x='Gender',y='Purchase',data=data,)
plt.show()

# %% [markdown]
# So, Here we can see that Male are speding more money .in shopping

# %%
#Lets plot City and Purchase
sns.barplot(x='City_Category',y='Purchase',data=data,)
plt.show()

# %% [markdown]
# Here we can see that From city C maximum order are make. then B then A are make orders

# %%
#Lets plot Martial and Purchase
sns.catplot(x='Marital_Status',y='Purchase',data=data,)
plt.show()

# %% [markdown]
# Here , We can see that Married and Unmarried Purchare amount are same in conts.

# %%
#Lets plot Age and Purchase
sns.barplot(x='Age',y='Purchase',data=data,)
plt.show()

# %% [markdown]
# Here , We can see that Maximum money spend from 51-55 age group then 55+ then 36-45  and 18-25 are same then 0.-17

# %%
#Lets plot Occupation and Purchase
sns.barplot(x='Occupation',y='Purchase',data=data)
plt.show()

# %% [markdown]
# So, Here maximum spended Occupation 17 then 12 then 15 then 8 then  7 then 5 and 7 . and Least Money spend from Occupation 9 then 19and 1 then 20 and 2 then 0.

# %%
#Lets plot Occupation and Purchase
sns.catplot(x='Gender',y='Age',data=data)
plt.show()

# %% [markdown]
# Here we can see that. Female and Male is equal in all age groups.

# %% [markdown]
# # MultiVariate Analysis

# %%
#Lets plot  Product Category 1 with Purchase with Gender
sns.barplot(x='Product_Category_1',y='Purchase',hue='Gender',data=data)
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here We can see that Maximum Price Product - 10 then 7 then 6 then 15 and 16 male and female order in almose same amount
#
# Least Price Product -> 19 then 20 then 13 then 12 then 4 then 18 then 11 the 5.male and female order in almose same amount

# %%
#Lets plot  Product Category 2 with Purchase with Gender
sns.barplot(x='Product_Category_2',y='Purchase',hue='Gender',data=data)
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that for .
#
# Maximum Price Product ,
#
# Product 10 -> Mamimum Order by Male and then Femalo
#
# Product 2.0 -> Maximum Order By Female then Male
#
# Product 6.0-> Maximum Order By Male then Female
#
# Product 3.0 -> Maximum Order By Male then Female
#
# Product 4.0 -> Maximum Order by Female then Male
#
# Product 15.0, 16.0 -> Maximum Order By male and then Female
#
#
# Less Price Product ->
#
# Product 7.0  -> Equally Order by male and Female
#
# Product 12.0 -> Maximum order by female then male
#
# Product 14.0 -. Maximum order by Male then Female
#
# Product 18.0 -. Maximum order by Male then Female

# %%
#Lets plot  Product Category 3 with Purchase with Gender
sns.barplot(x='Product_Category_3',y='Purchase',hue='Gender',data=data)
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that for .
#
# Maximum Price Product ,
#
# Product 3 -> Mamimum Order by Male and then Female
#
# Product 10 -> Maximum Order By Male and then Female
#
# Product 6.0-> Maximum Order By Male then Female
#
# Product 13 -> Maximum Order By Male then Female
#
# Product 8.0 -> Maximum Order by Male then Female
#
# Product 11.0 -> Maximum Order By Male then Female
#
# Product 5.0 -> Maximum Order By Female then Male
#
# Product 18.0 -> Maximum Order By Female then Male
#
#
# Less Price Product ->
#
# Product 4.0  -> Maximum order by female then male
#
# Product 12.0 -> Maximum order by female then male
#
# Product 14.0 -. Maximum order by Male then Female
#
# Product 18.0 -. Maximum order by Male then Female
#
# Product 9.0 -. Maximum order by Male then Female

# %%
#Lets plot  Product Category 3 with Purchase with Martial Status
sns.barplot(x='Product_Category_3',y='Purchase',hue='Marital_Status',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that for .
#
# Maximum Price Product Order By Married or UnMarried ,
#
# Product 3 -> Mamimum Order by 0 and then 1
#
# Product 10 -> Maximum Order By 1 and then 0
#
# Product 6.0-> Maximum Order By 0 then 1
#
# Product 13 -> Maximum Order By 1 then 0
#
# Product 8.0 -> Equally order by 0 and 1
#
# Product 11.0 -> Maximum Order By 0 then 1
#
# Product 5.0 -> Maximum Order By 1 then 0
#
# Product 18.0 -> Maximum Order 1 Female then 0
#
#
# Less Price Product ->
#
# Product 4.0  -> Maximum order by 1 then 0
#
# Product 12.0 -> Maximum order by 1 then 0
#
# Product 14.0 -. Maximum order by 0 then 1
#
# Product 18.0 -. Maximum order by 1 then 0
#
# Product 9.0 -. Maximum order by 0 then 1

# %%
#Lets plot  Product Category 2 with Purchase with Martial Status
sns.barplot(x='Product_Category_2',y='Purchase',hue='Marital_Status',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that for .
#
# Maximum Price Product ,
#
# Product 10 -> Equal order by 0 and 1
#
# Product 2.0 -> Maximum Order By 1 then 0
#
# Product 6.0-> Equal order by 0 and 1
#
# Product 3.0 -> Maximum Order By 1 then 0
#
# Product 4.0 -> Maximum Order by 1 then 0
#
# Product 15.0, 16.0 -> Maximum Order By 0 and then 1
#
#
# Less Price Product ->
#
# Product 7.0  -Maximum order by 0 then 1
#
# Product 12.0 -> Maximum order by 1 then 0
#
# Product 14.0 -> Equal order by 0 and 1
#
# Product 18.0 -> Equal order by 0 and 1

# %%
#Lets plot  Product Category 1 with Purchase with Martial Status
sns.barplot(x='Product_Category_1',y='Purchase',hue='Marital_Status',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here We can see that Maximum Price Product - 10 then 7 then 6 then 15 and 16 male and female order in almose same amount
#
# Least Price Product -> 19 then 20 then 13 then 12 then 4 then 18 then 11 the 5.male and female order in almose same amount

# %%
#Lets plot  Product Category 1 with Purchase with City Category
sns.barplot(x='Product_Category_1',y='Purchase',hue='City_Category',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that Maximum Price Product Order From -> C city then B the  A .
#
#
# and Some Products Like 12, 13, 20, 18 and 19 which are order same in all city

# %%
#Lets plot  Product Category 2 with Purchase with City Category
sns.barplot(x='Product_Category_2',y='Purchase',hue='City_Category',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that Maximum Price Product Order From -> C city then B the  A .
#
#
# and Some Products Like 18,17,5,4,and 3 order same by City C and B

# %%
#Lets plot  Product Category 3 with Purchase with City Category
sns.barplot(x='Product_Category_3',y='Purchase',hue='City_Category',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# So, Here we can see that Maximum Price Product Order From -> C city then B the  A .
#
#
# and  Product 3.0 -> Is Equally Order by city A , B and C .
#
# and Product 11 the only product which is order by City A .

# %%
#Lets plot  Product Category 3 with Purchase with Stay_In_Current_City_Years
sns.barplot(x='Product_Category_3',y='Purchase',hue='Stay_In_Current_City_Years',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
#Lets plot  Product Category 2 with Purchase with Stay_In_Current_City_Years
sns.barplot(x='Product_Category_2',y='Purchase',hue='Stay_In_Current_City_Years',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
#Lets plot  Product Category 3 with Purchase with Stay_In_Current_City_Years
sns.barplot(x='Product_Category_3',y='Purchase',hue='Stay_In_Current_City_Years',data=data,palette = 'colorblind',color='b'and 'green')
plt.xlabel("Prducts By Numbers")
plt.ylabel("Purchase Amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#Lets delete 2 Unncessory Columns
new_df=data.drop(columns=['User_ID','Product_ID'],axis=1)

# %%
#Lets plot Line Plot for checking the relation between feature and label
for i in new_df:
    plt.figure()
    sns.lineplot(x=new_df[i],y=new_df['Purchase'])
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# We don’t check for outliers and Distribution plot for all columns because we don’t need to check because column are Float and Int Type but it’s a Categorical data .
#
#
#
# And I decide to fill null or remove null after model building in both types. Without null or fill null. So then I decide null is important or not.

# %% [markdown]
# EDA is Done  . Lets Do Preprocessing done ,
#
#     and Our Task is to done EDA only .. So here we stop the project ...

# %%
#Student of DataTrained  - DataTrained
#Student of Data Science - Saurav
#Time - 22:06
#Date -> 02-03-2023
