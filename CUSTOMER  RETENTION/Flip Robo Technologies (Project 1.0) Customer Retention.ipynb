# %% [markdown]
# # Flip Robo Technologies

# %% [markdown]
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
#
#
#
#
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.

# %% [markdown]
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
#
#
#
#
#
#
#
#
#
#
#
# Need not to create machine learning models /but still if anybody comes with it that is welcome.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Disclaimer: The datasets and figure(s) are highly confidential. Any kind of commercial activities find with the content will be taken strict action. The dataset is only available for academic purpose.

# %% [markdown]
# Always refer to a Scikit-Learn Web Site for information about syntax and algorithms - https://scikit-learn.org/stable/index.html

# %% [markdown]
# # Lets Load Dataset

# %%
#Import Necessary Libraries to load Dataset
import pandas as pd

# %%
data=pd.read_excel(r"C:\Users\shriv\OneDrive\Desktop\customer_retention_dataset.xlsx")
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Lets check the shape of the datset
data.shape
# Out:
# (269, 71)

# %% [markdown]
# So , Here we have 269 rows and 71 columns

# %%
#Lets check the all columns name
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
#Lets check the data type of dataset
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#Lets check the info about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# So ,Here we have 1 integer columns (What is the Pin Code of where you shop online from?) and all are the object type data.

# %%
#Lets check the null values
data.isna().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# Here , We dont any null values .

# %%
#Lets check in heatmap there is nan values or not ?
#First import visualization tools for plot Heatmap

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Lets plot heatmap for checking nana
plt.figure(figsize=(20,15),facecolor='red')
sns.heatmap(data.isnull())
plt.savefig('isnull.png')

# %% [markdown]
# So , Here we confirming . There is no null values .

# %% [markdown]
# # Exploratory Data Analysis:

# %%
#Checking 1st Columns 1Gender of respondent (Using Countpplot)
plt.figure(figsize=(5,4),facecolor='blue')
sns.countplot(x='1Gender of respondent',data=data)
plt.savefig("1Gender of respondent.png")
data['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# Here we can see that Gender of respondent is ,
#
#
#
# Male - 88
#
#
# Female - 181

# %%
#Checking 2nc Column 2 How old are you? (Using Countplot)

sns.countplot(x="2 How old are you? ",data=data)
plt.savefig('2 How old are you.png')
data['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# Here we can se that ,
#
# 81 of the customers are from age group 31-40 years.
#
#
# 79 of the customers are form age froup 21-30 years.
#
#
# 70 of the customer are from age from 41-50 years
#
#
# 20 of the customer are less then 20 year old
#
#
#
# 19 of the customer are above 51 years old

# %%
#Checking the 3rd Columns Which city do you shop online from?
plt.figure(figsize=(20,15))
sns.countplot(x='3 Which city do you shop online from?',data=data)
plt.savefig('3 Which city do you shop online from.png')
data['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# Majority, 58 of the customers placed the order at Delhi city

# %%
#Lets plot 4th columns(''4 What is the Pin Code of where you shop online from?'')
plt.figure(figsize=(12,10))
sns.countplot(x='4 What is the Pin Code of where you shop online from?',data=data)
plt.xticks(rotation='vertical')
plt.savefig('4 What is the Pin Code of where you shop online from.png')
data['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %% [markdown]
# Majority, 38 of the customers placed an order from the pincode 201308.

# %%
#Lets plot 5th Columns '5 Since How Long You are Shopping Online ?'
plt.figure(figsize=(20,15))
sns.countplot(x='5 Since How Long You are Shopping Online ?',data=data)
plt.savefig('5 Since How Long You are Shopping Online.png')
data['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# Here we can see that ."5 Since How Long You are Shopping Online"
#
# More then 4 years - 98 people are using
#
#
# 3 - 4 Years - 65
#
#
# 2 - 3 Years - 47
#
#
# Less the One Year - 43
#
#
# 1-2 Year - 16

# %%
#Lets plot 6th columns (''6 How many times you have made an online purchase in the past 1 year?'')
plt.figure(figsize=(20,15))
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',data=data)
plt.savefig('6 How many times you have made an online purchase in the past 1 year.png')
data['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# Here we can see theat ('' How many times you have made an online purchase in the past 1 year?)
#
# Less than 10 times  -  114 People
#
#
# 31-40 times         -   63 People
#
#
# 41 times and above  -   47 People
#
#
#
# 11-20 times         -  29 People
#
#
#
# 21-30 times         -   10 People
#
#
#
# 42 times and above    - 6 People

# %%
#Lets plot 7th Columns('7 How do you access the internet while shopping on-line?')
plt.figure(figsize=(20,15))
sns.countplot(x='7 How do you access the internet while shopping on-line?',data=data)
plt.savefig('7 How do you access the internet while shopping on-line.png')
data['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# # How do you access the internet while shopping on-line?
#
# Majority of the people are using Mobile data  - 142 People
#
#
# Wifi Uses - 76 People
#
#
# Mobile Internet - 74 People
#
#
# Dail up - 4

# %%
#Lets plot 8th columns ('8 Which device do you use to access the online shopping?')
plt.figure(figsize=(20,15))
sns.countplot(x='8 Which device do you use to access the online shopping?',data=data)
plt.savefig('8 Which device do you use to access the online shopping.png')
data['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# # Which device do you use to access the online shopping?'
#
#
# Smartphone    141 Peoples
#
#
#
# Laptop         86 Peoples
#
#
#
#
# Desktop        30 Peoples
#
#
#
#
# Tablet         12 Peolpls

# %%
#Lets plot 9th Columns " What is the screen size of your mobile device?\t\t\t\t\t\t"
plt.figure(figsize=(20,15))
sns.countplot(x='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',data=data)
plt.savefig('9 What is the screen size of your mobile device.png')
data['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %% [markdown]
# # What is the screen size of your mobile device?
#
# Others        134 (Maybe its Computer)
#
#
# 5.5 inches     99
#
#
# 4.7 inches     29
#
#
#
# 5 inches        7

# %%
#Lets plot 9 to 13 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[9:13]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('9to13.png')

# %%
#Lets plot 13 to 17 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[13:17]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('13to17.png')

# %%
#Lets plot 17 to 21 columns in one code
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[17:21]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    
    plt.xticks(rotation=30)
plt.savefig('17to21.png')

# %%
#Lets plot 21 to 25 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[21:25]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('21to26.png')

# %%
#Lets plot 25 to 29 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[25:29]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('25to29.png')

# %%
#Lets plot 29 to 33 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[29:33]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('29to33.png')

# %%
#Lets plot 33 to 37 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[33:37]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('33to37.png')

# %%
#Lets plot 37 to 41 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[37:41]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('37to41.png')

# %%
#Lets plot 41 to 45 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[41:45]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('41to45.png')

# %%
#Lets plot 45 to 48 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[45:48]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('45to48.png')

# %%
#Lets plot 48 to 52 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[48:52]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('48to52.png')

# %%
#Lets plot 52 to 56 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[52:56]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('52to56.png')

# %%
#Lets plot 56 to 60 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[56:60]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('56to60.png')

# %%
#Lets plot 60 to 64 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[60:64]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('60to64.png')

# %%
#Lets plot 64 to 68 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[64:68]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('64to68.png')

# %%
#Lets plot 68 to 72 columns in one code .
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[68:72]:
    plt.subplot(2,2,plotnumber)
    plotnumber +=1
    ax=sns.countplot(y=data[col])
    plt.xticks(rotation=30)
plt.savefig('68to72.png')

# %%
#Lets plot 'Which of the Indian online retailer would you recommend to a friend?'
plt.figure(figsize=(20,15))
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(y=data['Which of the Indian online retailer would you recommend to a friend?'])
plt.show()

# %% [markdown]
# Here We can see that . Amazon is the best online shopping platform.

# %%
#Creating one Hot encode for Recommend online retailers

data['recommend_amazon'] = data['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('amazon.in') >=0) else 0  )

data['recommend_flipkart'] = data['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('flipkart') >=0) else 0  )

data['recommend_myntra'] = data['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('myntra') >=0) else 0  )

data['recommend_paytm'] = data['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('paytm') >=0) else 0  )

data['recommend_snapdeal'] = data['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('snapdeal')<=0)else 0)

# %%
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Lets plot the new featurs
plt.figure(figsize=(20,15))
plotnumber=1
for col in data.columns[71:]:
    if plotnumber <=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.countplot(x=data[col])
    plotnumber +=1
plt.savefig('New Columns')

# %%
#MultiVariate Analyse
sns.heatmap(data.corr(),annot=True)
plt.savefig('Multivariate')

# %% [markdown]
# CONCLUSION
#
#
#  Amazon is recommended by 81.4% of the customers.
#
#
#  Snapdeal is recommended by 4.1% of the customers.
#
#
#  Flipkart is recommended by 47.2 of the customers.
#
#
#  Myntra is recommended by 28% of the customers.
#
#
#  Paytm is recommended by 16% of the customer

# %% [markdown]
# # Conclusion .
#
#
#         As according to the dataset best online retailer they would recommend to a friend . Most of the respondents says Amazon because . It is providing all the feature that user want . Website is efficient and it is fast loading . it give complete relevant description and information of products. it is reliable and quick to complete the purchase . Amazom give speedy delivey to some places . customer and there is several payment option available . on the website . it provide online assistance through multichannels. providing good details on product . Amazon user friendly interface and has visual appealing webpage layout . Amazon also offers wide variety of product and its application is easy to use . Lastly the main thing why user recommend it is because of its trustworthiness and also its robust security in protecting customer financial information and their Privacy Information . Frequent distribution when moving from one page to another this company should see and improve it to give overall best experiance to the users . This paper investigated the factor that influence the online  customer repeat purchase intenstion . During the process various data processing method has been used to clean the data . The project conatains EDA considering every aspect . The major finding is complete relevant description  if products and reliability of the website increase chances of customer retetion. Howevee , if the content on the website is not easy to read and understand or can't guarantee the privacy of the customer will lead to chances of the customer retention . This project has increased my understanding of the concept . During the research i cam across various challenge and while solving them i learned a lot of new thing . How to plot different charts . . For example i learned how to plot subplot . How to How to group data and visualize that.

# %%
#Student of Data Science
#Student of DataTrained- Saurav
#Date - 12-11-22
#Time-10:05
